# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
# !pip install webdriver_manager --user
# Out:
# Requirement already satisfied: webdriver_manager in c:\users\natassha selvaraj\appdata\roaming\python\python37\site-packages (3.2.1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from webdriver_manager) (2.22.0)
# Requirement already satisfied: configparser in c:\users\natassha selvaraj\appdata\roaming\python\python37\site-packages (from webdriver_manager) (5.0.0)
# Requirement already satisfied: crayons in c:\programdata\anaconda3\lib\site-packages (from webdriver_manager) (0.3.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->webdriver_manager) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->webdriver_manager) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->webdriver_manager) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->webdriver_manager) (3.0.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from crayons->webdriver_manager) (0.4.3)

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# [WDM] - Current google-chrome version is 83.0.4103
# [WDM] - Get LATEST driver version for 83.0.4103
# [WDM] - Get LATEST driver version for 83.0.4103
# [WDM] - Trying to download new driver from http://chromedriver.storage.googleapis.com/83.0.4103.39/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\natassha selvaraj\.wdm\drivers\chromedriver\win32\83.0.4103.39]

# %%
driver.get('https://www.classcentral.com/subject/data-science')

# %%
# Data Science Courses
Course = []
Institute = []
Duration = []
Start_Date = []
Offered_By = []
No_Of_Reviews = []
Rating = []

# %%
content = driver.page_source
soup = BeautifulSoup(content)

# %%
def find_2nd(string, substring):
    return string.find(substring, string.find(substring) + 1)
def find_1st(string, substring):
    return string.find(substring, string.find(substring))

# %%
for i in soup.findAll("span",{'class' : 'text-1 weight-semi line-tight'}):
    b = str(i)
   # print(b[find_1st(b,'>')+1:find_2nd(b,'<')])
    Course.append(b[find_1st(b,'>')+1:find_2nd(b,'<')])

# %%
course = []
for i in Course:
    i = i.strip()
  #  print(i)
    course.append(i)

# %%
# Institute:
ins = []
for d in soup.findAll('div', attrs={'class':'truncate'}):
    abc = d.find('a', attrs={'class':'color-charcoal small-down-text-2 text-3'})
    if abc is not None:
        #print(rating.text)
        ins.append(abc.text)
    else:
        ins.append('-1')
        
newIns = []
for i in ins:
    i = i.strip()
    newIns.append(i)
newIns.pop(0)
# Out:
# '-1'

# %%
# lists: newIns, course

# %%
# Provider/Offered By:
for i in soup.findAll('a',href=True, attrs={'class':'color-charcoal italic'}):
    b = str(i)
    #print(b[find_1st(b,'>')+1:find_2nd(b,'<')])
    Offered_By.append(b[find_1st(b,'>')+1:find_2nd(b,'<')])
provider = []
for i in Offered_By:
    i = i.strip()
    provider.append(i)

# %%
# rating:
rat = []
for d in soup.findAll('div', attrs={'class':'col border-box text-center nowrap row large-up-text-right padding-horz-small push'}):
    abc = d.find('span', attrs={'class':'xlarge-up-hidden color-charcoal text-center'})
    if abc is not None:
        #print(rating.text)
        rat.append(abc.text)
    else:
        rat.append('-1')

# %%
for i in rat:
    i = i.strip()
    #print(i)
    Rating.append(i)

# %%
# Variables: newIns, course, provider, Rating

# %%
# Num of Reviews
for i in soup.findAll("span",{'class' : 'large-down-hidden block line-tight text-4 color-gray'}):
    b = str(i)
  #  print(b[find_1st(b,'>')+1:find_2nd(b,'<')])
    No_Of_Reviews.append(b[find_1st(b,'>')+1:find_2nd(b,'<')])

# %%
num_reviews = []
for i in No_Of_Reviews:
    i = i.strip()
    #print(i)
    num_reviews.append(i) 
    
# Variables: newIns, course, provider, Rating, num_reviews

# %%
# rating:
t = []
for d in soup.findAll('div', attrs={'class':'small-down-text-2 text-3 row vert-align-middle'}):
    abc = d.find('span', attrs={'class':'hidden medium-up-inline-block small-down-text-2 text-3 large-up-margin-left-xxsmall icon-clock-charcoal icon-left'})
    if abc is not None:
        t.append(abc.text)
    else:
        t.append('-1')

# %%
duration = []
for i in t:
    i = i.strip()
    #print(i)
    duration.append(i)

# %%
durationn = []
for i in duration:
    i = ' '.join(i.split())
    i = i.replace('\n','')
    durationn.append(i)

# %%
# Variables: newIns, course, provider, Rating, num_reviews, duration

# %%
dfDS = pd.DataFrame({'course':course,'ratings': Rating,'No_of_Reviews':num_reviews,
                  'provider':provider, 'institute':newIns, 'Duration':durationn})
dfDS
# Out:
#                                                course ratings No_of_Reviews  \
# 0                                       R Programming     2.7   243 Reviews
# 1                        The Data Scientist’s Toolbox     3.3   163 Reviews
# 2                                  The Analytics Edge     4.6    79 Reviews
# 3                               Become a Data Analyst     4.5    64 Reviews
# 4                           Getting and Cleaning Data     3.5    56 Reviews
# 5              Introduction to Data Science in Python     2.5    44 Reviews
# 6                           Exploratory Data Analysis     3.9    38 Reviews
# 7                             Python for Data Science     4.4    43 Reviews
# 8                            Introduction to Big Data     2.7    35 Reviews
# 9                             Python for Data Science     4.4    39 Reviews
# 10                              Statistical Inference     2.8    33 Reviews
# 11                                  Regression Models     2.5    33 Reviews
# 12                              Reproducible Research     3.9    26 Reviews
# 13                   Mastering Data Analysis in Excel     1.8    26 Reviews
# 14                  Making Sense of Data in the Media     4.7    25 Reviews
# 15          Hadoop Platform and Application Framework     1.9    25 Reviews
# 16                       Computational Social Science     4.8    30 Reviews
# 17  Introduction to Computational Thinking and Dat...     4.5    31 Reviews
# 18                 Introduction to R for Data Science     4.2    28 Reviews
# 19  Probability - The Science of Uncertainty and Data     4.9    29 Reviews
# 20                   Pattern Discovery in Data Mining     2.1    21 Reviews
# 21                            Mining Massive Datasets     4.6    25 Reviews
# 22                                 Data Visualization     3.3    20 Reviews
# 23                     A Crash Course in Data Science     3.4    20 Reviews
# 24  Spatial Data Science: The New Frontier in Anal...     4.9    27 Reviews
# 25                           Developing Data Products     3.9    18 Reviews
# 26  Finding Hidden Messages in DNA (Bioinformatics I)     4.5    17 Reviews
# 27             Process Mining: Data science in Action     4.4    17 Reviews
# 28  Whole genome sequencing of bacterial genomes -...     4.8    21 Reviews
# 29            Introduction to Python for Data Science     3.9    21 Reviews
# 30                      Intro to Hadoop and MapReduce     3.9    20 Reviews
# 31                                   Statistics and R     3.5    20 Reviews
# 32  Statistical Thinking for Data Science and Anal...     2.2    19 Reviews
# 33                               Data Analysis with R     4.6    18 Reviews
# 34                                           Big Data     1.5    18 Reviews
# 35                    Python for Genomic Data Science     2.4    12 Reviews
# 36                       Building a Data Science Team     3.5    12 Reviews
# 37  Probability and Statistics in Data Science usi...     1.9    18 Reviews
# 38                          Text Mining and Analytics     3.7    10 Reviews
# 39                          Data Science in Real Life     3.0    10 Reviews
# 40                    DCO042 - Python For Informatics     4.6    14 Reviews
# 41          Aprendizaje automático y ciencia de datos     4.5    14 Reviews
# 42  Biology Meets Programming: Bioinformatics for ...     3.4     9 Reviews
# 43  Bayesian Statistics: From Concept to Data Anal...     3.7     9 Reviews
# 44  Data Visualization and Communication with Tableau     3.8     9 Reviews
# 45                              Intro to Data Science     4.2    13 Reviews
# 46                   Intro to Python for Data Science     4.3    13 Reviews
# 47                Data Analysis: Take It to the MAX()     3.4    13 Reviews
# 48          Analyzing and Visualizing Data with Excel     4.2    13 Reviews
# 49                                  Introduction to R     3.8    12 Reviews
#
#        provider                                   institute  \
# 0      Coursera                    Johns Hopkins University
# 1      Coursera                    Johns Hopkins University
# 2           edX       Massachusetts Institute of Technology
# 3       Udacity                                      Kaggle
# 4      Coursera                    Johns Hopkins University
# 5      Coursera                      University of Michigan
# 6      Coursera                    Johns Hopkins University
# 7           edX         University of California, San Diego
# 8      Coursera         University of California, San Diego
# 9        Swayam       Indian Institute of Technology Madras
# 10     Coursera                    Johns Hopkins University
# 11     Coursera                    Johns Hopkins University
# 12     Coursera                    Johns Hopkins University
# 13     Coursera                             Duke University
# 14  FutureLearn                 The University of Sheffield
# 15     Coursera         University of California, San Diego
# 16     Coursera             University of California, Davis
# 17          edX       Massachusetts Institute of Technology
# 18          edX                                   Microsoft
# 19          edX       Massachusetts Institute of Technology
# 20     Coursera  University of Illinois at Urbana-Champaign
# 21          edX                         Stanford University
# 22     Coursera  University of Illinois at Urbana-Champaign
# 23     Coursera                    Johns Hopkins University
# 24  Independent                                        Esri
# 25     Coursera                    Johns Hopkins University
# 26     Coursera         University of California, San Diego
# 27     Coursera          Eindhoven University of Technology
# 28     Coursera       Technical University of Denmark (DTU)
# 29          edX                                   Microsoft
# 30      Udacity                                    Cloudera
# 31          edX                          Harvard University
# 32          edX                         Columbia University
# 33      Udacity                                    Facebook
# 34     Coursera         University of California, San Diego
# 35     Coursera                    Johns Hopkins University
# 36     Coursera                    Johns Hopkins University
# 37          edX         University of California, San Diego
# 38     Coursera  University of Illinois at Urbana-Champaign
# 39     Coursera                    Johns Hopkins University
# 40  Independent                      University of Michigan
# 41          edX         Universitat Politècnica de València
# 42     Coursera         University of California, San Diego
# 43     Coursera        University of California, Santa Cruz
# 44     Coursera                             Duke University
# 45      Udacity                                          -1
# 46     Datacamp                                          -1
# 47          edX              Delft University of Technology
# 48          edX                                   Microsoft
# 49     Datacamp                                          -1
#
#                               Duration
# 0      7-9 hours a week , 4 weeks long
# 1      1-4 hours a week , 4 weeks long
# 2   10-15 hours a week , 13 weeks long
# 3      10 hours a week , 17 weeks long
# 4      4-9 hours a week , 4 weeks long
# 5                                   -1
# 6      4-9 hours a week , 4 weeks long
# 7    8-10 hours a week , 10 weeks long
# 8                                   -1
# 9                                   -1
# 10     7-9 hours a week , 4 weeks long
# 11     4-9 hours a week , 4 weeks long
# 12     4-9 hours a week , 4 weeks long
# 13                                  -1
# 14       3 hours a week , 3 weeks long
# 15                                  -1
# 16     10 hours a week , 17 weeks long
# 17   14-16 hours a week , 9 weeks long
# 18     2-3 hours a week , 4 weeks long
# 19  10-14 hours a week , 16 weeks long
# 20     4-6 hours a week , 4 weeks long
# 21    5-10 hours a week , 7 weeks long
# 22     4-6 hours a week , 4 weeks long
# 23                                  -1
# 24     2-3 hours a week , 6 weeks long
# 25     4-9 hours a week , 4 weeks long
# 26    4-10 hours a week , 5 weeks long
# 27     4-6 hours a week , 6 weeks long
# 28     2-3 hours a week , 5 weeks long
# 29     2-4 hours a week , 6 weeks long
# 30                                  -1
# 31     2-4 hours a week , 4 weeks long
# 32    7-10 hours a week , 5 weeks long
# 33                                  -1
# 34      7 hours a week , 21 weeks long
# 35     3-5 hours a week , 4 weeks long
# 36                                  -1
# 37  10-12 hours a week , 10 weeks long
# 38    5-10 hours a week , 6 weeks long
# 39                                  -1
# 40                                  -1
# 41     4-5 hours a week , 5 weeks long
# 42    8-12 hours a week , 4 weeks long
# 43                                  -1
# 44                                  -1
# 45                                  -1
# 46                                  -1
# 47     4-6 hours a week , 8 weeks long
# 48     2-4 hours a week , 6 weeks long
# 49                                  -1

# %%
# Rating:
import numpy as np
dfDS['ratings'] = dfDS['ratings'].astype(float)
dfRating = dfDS.dropna()
dfRating = dfRating[dfRating.ratings != -1]
np.mean(dfRating['ratings']) # mean rating is 3.66
# Out:
# 3.648

# %%
# Visualization - Imports:

import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
# %matplotlib inline
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.express as px
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import chart_studio
username = 'natassha' # your username
api_key = 'RiCPKhGKzUyqSRt6KXlN' # your api key - go to profile > settings > regenerate key
chart_studio.tools.set_credentials_file(username=username, api_key=api_key)

# %%
# All course ratings

fig = px.histogram(dfRating, x="ratings")
fig.update_traces(marker_color="turquoise",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='DS Ratings')
fig.show()
py.plot(fig)
# Out:
# <div>
#
#
#             <div id="78516d42-a610-4dd0-8abb-46e102f81a9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("78516d42-a610-4dd0-8abb-46e102f81a9b")) {
#                     Plotly.newPlot(
#                         '78516d42-a610-4dd0-8abb-46e102f81a9b',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "ratings=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "turquoise", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [2.7, 3.3, 4.6, 4.5, 3.5, 2.5, 3.9, 4.4, 2.7, 4.4, 2.8, 2.5, 3.9, 1.8, 4.7, 1.9, 4.8, 4.5, 4.2, 4.9, 2.1, 4.6, 3.3, 3.4, 4.9, 3.9, 4.5, 4.4, 4.8, 3.9, 3.9, 3.5, 2.2, 4.6, 1.5, 2.4, 3.5, 1.9, 3.7, 3.0, 4.6, 4.5, 3.4, 3.7, 3.8, 4.2, 4.3, 3.4, 4.2, 3.8], "xaxis": "x", "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...
# 'https://plotly.com/~natassha/84/'

# %%
# No.of.Reviews:
dfRating['No_of_Reviews'] = dfRating['No_of_Reviews'].str.extract('(\d+)', expand=False).astype(int)
# average no of reviews:
np.mean(dfRating['No_of_Reviews']) # 31.3
# Out:
# 31.46

# %%
# Num of Reviews- all courses
fig = px.histogram(dfRating, x="No_of_Reviews")
fig.update_traces(marker_color="turquoise",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Num of Reviews')
py.plot(fig)
fig.show()
# Out:
# <div>
#
#
#             <div id="4ef79cb2-5fe9-49f2-8a13-b09a513d5b05" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4ef79cb2-5fe9-49f2-8a13-b09a513d5b05")) {
#                     Plotly.newPlot(
#                         '4ef79cb2-5fe9-49f2-8a13-b09a513d5b05',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "No_of_Reviews=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "turquoise", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [243, 163, 79, 64, 56, 44, 38, 43, 35, 39, 33, 33, 26, 26, 25, 25, 30, 31, 28, 29, 21, 25, 20, 20, 27, 18, 17, 17, 21, 21, 20, 20, 19, 18, 18, 12, 12, 18, 10, 10, 14, 14, 9, 9, 9, 13, 13, 13, 13, 12], "xaxis": "x", "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %%
# best courses - highest rated:

bestRated = dfRating.loc[(dfRating['No_of_Reviews'] >= 20) & 
                         (dfRating['ratings'] >= 4)]

# %%
bestRated
# Out:
#                                                course  ratings  No_of_Reviews  \
# 2                                  The Analytics Edge      4.6             79
# 3                               Become a Data Analyst      4.5             64
# 7                             Python for Data Science      4.4             43
# 9                             Python for Data Science      4.4             39
# 14                  Making Sense of Data in the Media      4.7             25
# 16                       Computational Social Science      4.8             30
# 17  Introduction to Computational Thinking and Dat...      4.5             31
# 18                 Introduction to R for Data Science      4.2             28
# 19  Probability - The Science of Uncertainty and Data      4.9             29
# 21                            Mining Massive Datasets      4.6             25
# 24  Spatial Data Science: The New Frontier in Anal...      4.9             27
# 28  Whole genome sequencing of bacterial genomes -...      4.8             21
#
#        provider                              institute  \
# 2           edX  Massachusetts Institute of Technology
# 3       Udacity                                 Kaggle
# 7           edX    University of California, San Diego
# 9        Swayam  Indian Institute of Technology Madras
# 14  FutureLearn            The University of Sheffield
# 16     Coursera        University of California, Davis
# 17          edX  Massachusetts Institute of Technology
# 18          edX                              Microsoft
# 19          edX  Massachusetts Institute of Technology
# 21          edX                    Stanford University
# 24  Independent                                   Esri
# 28     Coursera  Technical University of Denmark (DTU)
#
#                               Duration
# 2   10-15 hours a week , 13 weeks long
# 3      10 hours a week , 17 weeks long
# 7    8-10 hours a week , 10 weeks long
# 9                                   -1
# 14       3 hours a week , 3 weeks long
# 16     10 hours a week , 17 weeks long
# 17   14-16 hours a week , 9 weeks long
# 18     2-3 hours a week , 4 weeks long
# 19  10-14 hours a week , 16 weeks long
# 21    5-10 hours a week , 7 weeks long
# 24     2-3 hours a week , 6 weeks long
# 28     2-3 hours a week , 5 weeks long

# %%
# best rated course providers:
# pie chart:

dist = bestRated['provider'].value_counts()
colors = ['mediumturquoise', 'darkorange', 'gold', 'lightgreen']
trace = go.Pie(values=(np.array(dist)),labels=dist.index)
layout = go.Layout(title='Best Rated DS Course Provider')
data = [trace]
fig = go.Figure(trace,layout)
fig.update_traces(marker=dict(colors=colors, line=dict(color='#000000', width=2)))
fig.show() 
py.plot(fig)
# Out:
# <div>
#
#
#             <div id="c79ca9f4-e636-4780-bd15-52642e5438ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c79ca9f4-e636-4780-bd15-52642e5438ce")) {
#                     Plotly.newPlot(
#                         'c79ca9f4-e636-4780-bd15-52642e5438ce',
#                         [{"labels": ["edX", "Coursera", "Udacity", "Independent", "FutureLearn", "Swayam"], "marker": {"colors": ["mediumturquoise", "darkorange", "gold", "lightgreen"], "line": {"color": "#000000", "width": 2}}, "type": "pie", "values": [6, 2, 1, 1, 1, 1]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...
# 'https://plotly.com/~natassha/92/'

# %%
# best rated DS institute counts:

institute_count= pd.DataFrame({'institute':bestRated["institute"].value_counts().index, 'counts':bestRated["institute"].value_counts().values}).sort_values("counts")
fig = px.bar(institute_count, x='institute', y='counts')
fig.update_traces(marker_color="turquoise",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Best Rated DS Institute')
py.plot(fig)
fig.show()
# Out:
# <div>
#
#
#             <div id="8f5f734f-13f8-44d6-9ad5-e0aa6f1eb654" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8f5f734f-13f8-44d6-9ad5-e0aa6f1eb654")) {
#                     Plotly.newPlot(
#                         '8f5f734f-13f8-44d6-9ad5-e0aa6f1eb654',
#                         [{"alignmentgroup": "True", "hovertemplate": "institute=%{x}<br>counts=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "turquoise", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["University of California, Davis", "The University of Sheffield", "Esri", "Indian Institute of Technology Madras", "University of California, San Diego", "Kaggle", "Stanford University", "Microsoft", "Technical University of Denmark (DTU)", "Massachusetts Institute of Technology"], "xaxis": "x", "y": [1, 1, 1, 1, 1, 1, 1, 1, 1, 3], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %%
bestRated
# Out:
#                                                course  ratings  No_of_Reviews  \
# 2                                  The Analytics Edge      4.6             79
# 3                               Become a Data Analyst      4.5             64
# 7                             Python for Data Science      4.4             43
# 9                             Python for Data Science      4.4             39
# 14                  Making Sense of Data in the Media      4.7             25
# 16                       Computational Social Science      4.8             30
# 17  Introduction to Computational Thinking and Dat...      4.5             31
# 18                 Introduction to R for Data Science      4.2             28
# 19  Probability - The Science of Uncertainty and Data      4.9             29
# 21                            Mining Massive Datasets      4.6             25
# 24  Spatial Data Science: The New Frontier in Anal...      4.9             27
# 28  Whole genome sequencing of bacterial genomes -...      4.8             21
#
#        provider                              institute  \
# 2           edX  Massachusetts Institute of Technology
# 3       Udacity                                 Kaggle
# 7           edX    University of California, San Diego
# 9        Swayam  Indian Institute of Technology Madras
# 14  FutureLearn            The University of Sheffield
# 16     Coursera        University of California, Davis
# 17          edX  Massachusetts Institute of Technology
# 18          edX                              Microsoft
# 19          edX  Massachusetts Institute of Technology
# 21          edX                    Stanford University
# 24  Independent                                   Esri
# 28     Coursera  Technical University of Denmark (DTU)
#
#                               Duration
# 2   10-15 hours a week , 13 weeks long
# 3      10 hours a week , 17 weeks long
# 7    8-10 hours a week , 10 weeks long
# 9                                   -1
# 14       3 hours a week , 3 weeks long
# 16     10 hours a week , 17 weeks long
# 17   14-16 hours a week , 9 weeks long
# 18     2-3 hours a week , 4 weeks long
# 19  10-14 hours a week , 16 weeks long
# 21    5-10 hours a week , 7 weeks long
# 24     2-3 hours a week , 6 weeks long
# 28     2-3 hours a week , 5 weeks long

# %%
# Best Rated Courses:

bestRated.loc[7,'course'] = 'Python for Data Science edX'
bestRated.loc[9,'course'] = 'Python for Data Science Swayam'

fig = px.bar(bestRated, x='course', y='ratings')
fig.update_traces(marker_color="turquoise",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Highest Rated DS Courses')
py.plot(fig)
fig.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>
#
#
#             <div id="dbc60819-095a-445d-8792-2d3264438870" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dbc60819-095a-445d-8792-2d3264438870")) {
#                     Plotly.newPlot(
#                         'dbc60819-095a-445d-8792-2d3264438870',
#                         [{"alignmentgroup": "True", "hovertemplate": "course=%{x}<br>ratings=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "turquoise", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["The Analytics Edge", "Become a Data Analyst", "Python for Data Science edX", "Python for Data Science Swayam", "Making Sense of Data in the Media", "Computational Social Science", "Introduction to Computational Thinking and Data Science", "Introduction to R for Data Science", "Probability - The Science of Uncertainty and Data", "Mining Massive Datasets", "Spatial Data Science: The New Frontier in Analytics", "Whole genome sequencing of bacterial genomes - tools and applications"], "xaxis": "x", "y": [4.6, 4.5, 4.4, 4.4, 4.7, 4.8, 4.5, 4.2, 4.9, 4.6, 4.9, 4.8], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %%
# Best Courses & Num of Reviews

fig = px.bar(bestRated, x='course', y='No_of_Reviews')
fig.update_traces(marker_color="turquoise",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Best Course Num of Reviews')
py.plot(fig)
fig.show()
# Out:
# <div>
#
#
#             <div id="03adfcda-b260-4525-a358-8465c09e0590" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("03adfcda-b260-4525-a358-8465c09e0590")) {
#                     Plotly.newPlot(
#                         '03adfcda-b260-4525-a358-8465c09e0590',
#                         [{"alignmentgroup": "True", "hovertemplate": "course=%{x}<br>No_of_Reviews=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "turquoise", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["The Analytics Edge", "Become a Data Analyst", "Python for Data Science edX", "Python for Data Science Swayam", "Making Sense of Data in the Media", "Computational Social Science", "Introduction to Computational Thinking and Data Science", "Introduction to R for Data Science", "Probability - The Science of Uncertainty and Data", "Mining Massive Datasets", "Spatial Data Science: The New Frontier in Analytics", "Whole genome sequencing of bacterial genomes - tools and applications"], "xaxis": "x", "y": [79, 64, 43, 39, 25, 30, 31, 28, 29, 25, 27, 21], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %%
# Data Analysis Courses:

Duration = []
ratingg = []
reviewNum = []
title = []
providerr = []
institutee = []

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get('https://www.classcentral.com/subject/data-analysis')

content = driver.page_source
soup = BeautifulSoup(content)
# Out:
# [WDM] - Current google-chrome version is 83.0.4103
# [WDM] - Get LATEST driver version for 83.0.4103
# [WDM] - Driver [C:\Users\natassha selvaraj\.wdm\drivers\chromedriver\win32\83.0.4103.39\chromedriver.exe] found in cache

# %%
# course title
for i in soup.findAll("span",{'class' : 'text-1 weight-semi line-tight'}):
    b = str(i)
    #print(b[find_1st(b,'>')+1:find_2nd(b,'<')])
    title.append(b[find_1st(b,'>')+1:find_2nd(b,'<')])

# %%
coursetitle = []
for i in title:
    i = i.strip()
    coursetitle.append(i)

# %%
# Institute:
inst = []
for d in soup.findAll('div', attrs={'class':'truncate'}):
    abc = d.find('a', attrs={'class':'color-charcoal small-down-text-2 text-3'})
    if abc is not None:
        #print(rating.text)
        inst.append(abc.text)
    else:
        inst.append('-1')

# %%
newInstitute = []
for i in inst:
    i = i.strip()
    newInstitute.append(i)
newInstitute.pop(0)
# Out:
# '-1'

# %%
# variables: coursetitle, newInstitute

# %%
# Provider:

for i in soup.findAll('a',href=True, attrs={'class':'color-charcoal italic'}):
    b = str(i)
    #print(b[find_1st(b,'>')+1:find_2nd(b,'<')])
    providerr.append(b[find_1st(b,'>')+1:find_2nd(b,'<')])
analysisProv = []
for i in providerr:
    i = i.strip()
    analysisProv.append(i)

# %%
# variables: coursetitle, newInstitute, analysisProv

# %%
# rating:
rat_ = []
for d in soup.findAll('div', attrs={'class':'col border-box text-center nowrap row large-up-text-right padding-horz-small push'}):
    abc = d.find('span', attrs={'class':'xlarge-up-hidden color-charcoal text-center'})
    if abc is not None:
        #print(rating.text)
        rat_.append(abc.text)
    else:
        rat_.append('-1')

# %%
ratingg = []
for i in rat_:
    i = i.strip()
    ratingg.append(i)

# %%
aaaa = []
for d in soup.findAll('div', attrs={'class':'width-100'}):
    abc = d.find('span', attrs={'class':'large-down-hidden block line-tight text-4 color-gray'})
    if abc is not None:
        #print(rating.text)
        aaaa.append(abc.text)
    else:
        aaaa.append('-1')

# %%
revs = aaaa[8:-8]

# %%
for i in revs:
    i = i.strip()
    reviewNum.append(i)

# %%
# variables: coursetitle, newInstitute, analysisProv, ratingg, reviewNum

# %%
# duration:

t = []
for d in soup.findAll('div', attrs={'class':'small-down-text-2 text-3 row vert-align-middle'}):
    abc = d.find('span', attrs={'class':'hidden medium-up-inline-block small-down-text-2 text-3 large-up-margin-left-xxsmall icon-clock-charcoal icon-left'})
    if abc is not None:
        t.append(abc.text)
    else:
        t.append('-1')

dur = []
for i in t:
    i = i.strip()
    #print(i)
    dur.append(i) 
    
for i in dur:
    i = ' '.join(i.split())
    i = i.replace('\n','')
    Duration.append(i)

# %%
# variables: coursetitle, newInstitute, analysisProv, ratingg, reviewNum, Duration

# %%
# create dataframe:
dfAnalysis = pd.DataFrame({'course':coursetitle,'ratings': ratingg,'No_of_Reviews':reviewNum,
                  'provider':analysisProv, 'institute':newInstitute, 'Duration':Duration})
dfAnalysis
# Out:
#                                                course ratings No_of_Reviews  \
# 0                               Become a Data Analyst     4.5    64 Reviews
# 1                           Getting and Cleaning Data     3.5    56 Reviews
# 2                    Mastering Data Analysis in Excel     1.8    26 Reviews
# 3                           Exploratory Data Analysis     3.9    38 Reviews
# 4                                Data Analysis with R     4.6    18 Reviews
# 5   Bayesian Statistics: From Concept to Data Anal...     3.7     9 Reviews
# 6                 Data Analysis: Take It to the MAX()     3.4    13 Reviews
# 7          Framework for Data Collection and Analysis     3.5     2 Reviews
# 8                              Тренды и классификации      -1            -1
# 9   Big Data Analysis: Hive, Spark SQL, DataFrames...      -1            -1
# 10          Introduction to Data Analysis Using Excel     2.5     2 Reviews
# 11  Statistics for Researchers: Understanding Medi...      -1            -1
# 12       Data Analytics Foundations for Accountancy I     1.0     1 Reviews
# 13                           Healthcare Data Literacy      -1            -1
# 14                             Healthcare Data Models      -1            -1
# 15          Culminating Project in Health Informatics      -1            -1
# 16     Fitting Statistical Models to Data with Python      -1            -1
# 17                          Data Analysis with Python     4.0     1 Reviews
# 18                         مجموعة أدوات عالم البيانات      -1            -1
# 19        مهارات برنامج Excel للعمل: المبادئ الأساسية      -1            -1
# 20            Basic Data Processing and Visualization     3.0     1 Reviews
# 21                     Meaningful Predictive Modeling      -1            -1
# 22         Foundations for Big Data Analysis with SQL      -1            -1
# 23  Power and Sample Size for Multilevel and Longi...      -1            -1
# 24              Accounting Data Analytics with Python      -1            -1
# 25  AI Workflow: Data Analysis and Hypothesis Testing      -1            -1
# 26        Build Data Analysis tools using R and DPLYR      -1            -1
# 27  Serverless Data Analysis with Google BigQuery ...      -1            -1
# 28  Serverless Data Analysis with Google BigQuery ...      -1            -1
# 29  Serverless Data Analysis with Google BigQuery ...      -1            -1
# 30                            Social Network Analysis     5.0     4 Reviews
# 31                 COVID19 Data Analysis Using Python      -1            -1
# 32  Building Resilient Streaming Analytics Systems...      -1            -1
# 33  Building Resilient Streaming Analytics Systems...      -1            -1
# 34  Building Resilient Streaming Analytics Systems...      -1            -1
# 35  Building Resilient Streaming Analytics Systems...      -1            -1
# 36  Building Resilient Streaming Analytics Systems...      -1            -1
# 37               Applying Data Analytics in Marketing      -1            -1
# 38          Умная аналитика в управлении образованием      -1            -1
# 39      Big Data Analytical Platform on Alibaba Cloud      -1            -1
# 40  Smart Analytics, Machine Learning, and AI on G...      -1            -1
# 41  Smart Analytics, Machine Learning, and AI on G...      -1            -1
# 42  Smart Analytics, Machine Learning, and AI on G...      -1            -1
# 43  Smart Analytics, Machine Learning, and AI on G...      -1            -1
# 44  Smart Analytics, Machine Learning, and AI on G...      -1            -1
# 45          Introduction to Business Analytics with R      -1            -1
# 46         Introducción a los algoritmos de regresión      -1            -1
# 47  Survey Data Collection and Analytics Project (...      -1            -1
# 48              Sampling People, Networks and Records      -1            -1
# 49                        Social Media Data Analytics     3.5     2 Reviews
#
#     provider                                   institute  \
# 0    Udacity                                      Kaggle
# 1   Coursera                    Johns Hopkins University
# 2   Coursera                             Duke University
# 3   Coursera                    Johns Hopkins University
# 4    Udacity                                    Facebook
# 5   Coursera        University of California, Santa Cruz
# 6        edX              Delft University of Technology
# 7   Coursera        University of Maryland, College Park
# 8   Coursera                Novosibirsk State University
# 9   Coursera                                      Yandex
# 10  Coursera                             Rice University
# 11  Coursera                      University of Virginia
# 12  Coursera  University of Illinois at Urbana-Champaign
# 13  Coursera             University of California, Davis
# 14  Coursera             University of California, Davis
# 15  Coursera                    Johns Hopkins University
# 16  Coursera                      University of Michigan
# 17  Coursera                                         IBM
# 18  Coursera                    Johns Hopkins University
# 19  Coursera                        Macquarie University
# 20  Coursera         University of California, San Diego
# 21  Coursera         University of California, San Diego
# 22  Coursera                                    Cloudera
# 23  Coursera                       University of Florida
# 24  Coursera  University of Illinois at Urbana-Champaign
# 25  Coursera                                         IBM
# 26  Coursera                    Coursera Project Network
# 27  Coursera                                Google Cloud
# 28  Coursera                                Google Cloud
# 29  Coursera                                Google Cloud
# 30  Coursera             University of California, Davis
# 31  Coursera                    Coursera Project Network
# 32  Coursera                                Google Cloud
# 33  Coursera                                Google Cloud
# 34  Coursera                                Google Cloud
# 35  Coursera                                Google Cloud
# 36  Coursera                                Google Cloud
# 37  Coursera  University of Illinois at Urbana-Champaign
# 38  Coursera                  Higher School of Economics
# 39  Coursera                                     Alibaba
# 40  Coursera                                Google Cloud
# 41  Coursera                                Google Cloud
# 42  Coursera                                Google Cloud
# 43  Coursera                                Google Cloud
# 44  Coursera                                Google Cloud
# 45  Coursera  University of Illinois at Urbana-Champaign
# 46  Coursera                    Coursera Project Network
# 47  Coursera                      University of Michigan
# 48  Coursera                      University of Michigan
# 49  Coursera                          Rutgers University
#
#                                      Duration
# 0             10 hours a week , 17 weeks long
# 1             4-9 hours a week , 4 weeks long
# 2                                          -1
# 3             4-9 hours a week , 4 weeks long
# 4                                          -1
# 5                                          -1
# 6             4-6 hours a week , 8 weeks long
# 7                                          -1
# 8             4-6 hours a week , 5 weeks long
# 9                                          -1
# 10                                         -1
# 11                                         -1
# 12                                         -1
# 13            2-5 hours a week , 4 weeks long
# 14            2-3 hours a week , 4 weeks long
# 15              5 hours a week , 4 weeks long
# 16            4-6 hours a week , 4 weeks long
# 17              2 hours a week , 7 weeks long
# 18            1-4 hours a week , 4 weeks long
# 19                                         -1
# 20              9 hours a week , 5 weeks long
# 21              9 hours a week , 4 weeks long
# 22                                         -1
# 23            4-6 hours a week , 5 weeks long
# 24              8 hours a week , 8 weeks long
# 25            7-9 hours a week , 2 weeks long
# 26              5 hours a week , 1 weeks long
# 27            6-8 hours a week , 1 weeks long
# 28            6-8 hours a week , 1 weeks long
# 29            6-8 hours a week , 1 weeks long
# 30            5-7 hours a week , 5 weeks long
# 31            1-2 hours a week , 1 weeks long
# 32  12 hours worth of material , 2 weeks long
# 33  12 hours worth of material , 2 weeks long
# 34  12 hours worth of material , 2 weeks long
# 35  12 hours worth of material , 2 weeks long
# 36  12 hours worth of material , 2 weeks long
# 37            4-6 hours a week , 4 weeks long
# 38                                         -1
# 39  8 hours worth of material , 10 weeks long
# 40   8 hours worth of material , 2 weeks long
# 41   8 hours worth of material , 2 weeks long
# 42              8 hours a week , 2 weeks long
# 43   8 hours worth of material , 2 weeks long
# 44   8 hours worth of material , 2 weeks long
# 45              7 hours a week , 4 weeks long
# 46              1 hours a week , 1 weeks long
# 47                                         -1
# 48                                         -1
# 49                                         -1

# %%
dfAnalysis['ratings'] = dfAnalysis['ratings'].astype(float)
AnalysisRating = dfAnalysis.dropna()
AnalysisRating = AnalysisRating[AnalysisRating.ratings != -1]
np.mean(AnalysisRating['ratings']) # mean: 3.54
# Out:
# 3.4214285714285713

# %%
# Visualize Overall Rating:

fig = px.histogram(AnalysisRating, x="ratings")
fig.update_traces(marker_color="midnightblue",marker_line_color='black',
                  marker_line_width=1.5)
fig.update_layout(title_text='Data Analysis Course Ratings',xaxis=dict(range=[1, 5]))
fig.show()
py.plot(fig)
# Out:
# <div>
#
#
#             <div id="79274cd0-ec89-4add-9a34-9ef29a1959d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("79274cd0-ec89-4add-9a34-9ef29a1959d7")) {
#                     Plotly.newPlot(
#                         '79274cd0-ec89-4add-9a34-9ef29a1959d7',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "ratings=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "midnightblue", "line": {"color": "black", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [4.5, 3.5, 1.8, 3.9, 4.6, 3.7, 3.4, 3.5, 2.5, 1.0, 4.0, 3.0, 5.0, 3.5], "xaxis": "x", "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...
# 'https://plotly.com/~natassha/68/'

# %%
# No.of.Reviews:
AnalysisRating['No_of_Reviews'] = AnalysisRating['No_of_Reviews'].str.extract('(\d+)', expand=False).astype(int)
# average no of reviews:
np.mean(AnalysisRating['No_of_Reviews']) # 15.31
# Out:
# 16.928571428571427

# %%
# Num of Reviews- all courses

fig = px.histogram(AnalysisRating, x="No_of_Reviews")
fig.update_traces(marker_color="midnightblue",marker_line_color='black',
                  marker_line_width=1.5)
fig.update_layout(title_text='Data Analysis: Number of Reviews')
fig.show()
py.plot(fig)
# Out:
# <div>
#
#
#             <div id="ff20037a-a829-40a1-8a9b-79ba71e6c06e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ff20037a-a829-40a1-8a9b-79ba71e6c06e")) {
#                     Plotly.newPlot(
#                         'ff20037a-a829-40a1-8a9b-79ba71e6c06e',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "No_of_Reviews=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "midnightblue", "line": {"color": "black", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [64, 56, 26, 38, 18, 9, 13, 2, 2, 1, 1, 1, 4, 2], "xaxis": "x", "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...
# 'https://plotly.com/~natassha/72/'

# %%
# best courses - highest rated:

bestAnalysis = AnalysisRating.loc[(AnalysisRating['No_of_Reviews'] >= 5) & 
                         (AnalysisRating['ratings'] >= 3)]

# %%
bestAnalysis
# Out:
#                                               course  ratings  No_of_Reviews  \
# 0                              Become a Data Analyst      4.5             64
# 1                          Getting and Cleaning Data      3.5             56
# 3                          Exploratory Data Analysis      3.9             38
# 4                               Data Analysis with R      4.6             18
# 5  Bayesian Statistics: From Concept to Data Anal...      3.7              9
# 6                Data Analysis: Take It to the MAX()      3.4             13
#
#    provider                             institute  \
# 0   Udacity                                Kaggle
# 1  Coursera              Johns Hopkins University
# 3  Coursera              Johns Hopkins University
# 4   Udacity                              Facebook
# 5  Coursera  University of California, Santa Cruz
# 6       edX        Delft University of Technology
#
#                           Duration
# 0  10 hours a week , 17 weeks long
# 1  4-9 hours a week , 4 weeks long
# 3  4-9 hours a week , 4 weeks long
# 4                               -1
# 5                               -1
# 6  4-6 hours a week , 8 weeks long

# %%
# best rated course providers:
# pie chart:

dist = bestAnalysis['provider'].value_counts()
colors = ['mediumturquoise', 'darkorange', 'gold', 'lightgreen']
trace = go.Pie(values=(np.array(dist)),labels=dist.index)
layout = go.Layout(title='Best Rated Analysis Course Provider')
data = [trace]
fig = go.Figure(trace,layout)
fig.update_traces(marker=dict(colors=colors, line=dict(color='#000000', width=2)))
fig.show() 
py.plot(fig)
# Out:
# <div>
#
#
#             <div id="18d4eecc-a83e-46a0-84eb-d1278ed1eb10" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("18d4eecc-a83e-46a0-84eb-d1278ed1eb10")) {
#                     Plotly.newPlot(
#                         '18d4eecc-a83e-46a0-84eb-d1278ed1eb10',
#                         [{"labels": ["Coursera", "Udacity", "edX"], "marker": {"colors": ["mediumturquoise", "darkorange", "gold", "lightgreen"], "line": {"color": "#000000", "width": 2}}, "type": "pie", "values": [3, 2, 1]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...
# 'https://plotly.com/~natassha/78/'

# %%
# best rated DA institute counts:

institute_count= pd.DataFrame({'institute':bestAnalysis["institute"].value_counts().index, 'counts':bestAnalysis["institute"].value_counts().values}).sort_values("counts")
fig = px.bar(institute_count, x='institute', y='counts')
fig.update_traces(marker_color="midnightblue",marker_line_color='black',
                  marker_line_width=1.5)
fig.update_layout(title_text='Highest Rated DA Institute')
py.plot(fig)
fig.show()
# Out:
# <div>
#
#
#             <div id="48116a35-f270-44b9-8efa-d49bab2a6c41" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("48116a35-f270-44b9-8efa-d49bab2a6c41")) {
#                     Plotly.newPlot(
#                         '48116a35-f270-44b9-8efa-d49bab2a6c41',
#                         [{"alignmentgroup": "True", "hovertemplate": "institute=%{x}<br>counts=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "midnightblue", "line": {"color": "black", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Facebook", "Kaggle", "Delft University of Technology", "University of California, Santa Cruz", "Johns Hopkins University"], "xaxis": "x", "y": [1, 1, 1, 1, 2], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %%
# Best Rated Courses:

fig = px.bar(bestAnalysis, x='course', y='ratings')
fig.update_traces(marker_color="midnightblue",marker_line_color='black',
                  marker_line_width=3.5)
fig.update_layout(title_text='Highest Rated DA Courses')
py.plot(fig)
#fig.show()
# Out:
# 'https://plotly.com/~natassha/82/'

# %%
# Best Courses & Num of Reviews

fig = px.bar(bestAnalysis, x='course', y='No_of_Reviews')
fig.update_traces(marker_color="midnightblue",marker_line_color='black',
                  marker_line_width=1.5)
fig.update_layout(title_text='Best Analysis Courses: Num of Reviews')
py.plot(fig)
fig.show()
# Out:
# <div>
#
#
#             <div id="ebf69e11-8eb8-46a5-98d4-a5255cc75fb8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ebf69e11-8eb8-46a5-98d4-a5255cc75fb8")) {
#                     Plotly.newPlot(
#                         'ebf69e11-8eb8-46a5-98d4-a5255cc75fb8',
#                         [{"alignmentgroup": "True", "hovertemplate": "course=%{x}<br>No_of_Reviews=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "midnightblue", "line": {"color": "black", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Become a Data Analyst", "Getting and Cleaning Data", "Exploratory Data Analysis", "Data Analysis with R", "Bayesian Statistics: From Concept to Data Analysis", "Data Analysis: Take It to the MAX()"], "xaxis": "x", "y": [64, 56, 38, 18, 9, 13], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %%
# ML Courses:

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get('https://www.classcentral.com/subject/machine-learning')
# Out:
# [WDM] - Current google-chrome version is 83.0.4103
# [WDM] - Get LATEST driver version for 83.0.4103
# [WDM] - Driver [C:\Users\natassha selvaraj\.wdm\drivers\chromedriver\win32\83.0.4103.39\chromedriver.exe] found in cache

# %%
mlCourse = []
mlInstitute = []
mlProvider = []
mlRating = []
mlReview = []

content = driver.page_source
soup = BeautifulSoup(content)
for i in soup.findAll("span",{'class' : 'text-1 weight-semi line-tight'}):
    b = str(i)
  #  print(b[find_1st(b,'>')+1:find_2nd(b,'<')])
    mlCourse.append(b[find_1st(b,'>')+1:find_2nd(b,'<')])

# %%
mlCoursee = []
for i in mlCourse:
    i = i.strip()
    #print(i)
    mlCoursee.append(i)

# %%
# Institute:
inss = []
for d in soup.findAll('div', attrs={'class':'truncate'}):
    abc = d.find('a', attrs={'class':'color-charcoal small-down-text-2 text-3'})
    if abc is not None:
        #print(rating.text)
        inss.append(abc.text)
    else:
        inss.append('-1')

for i in inss:
    i = i.strip()
    mlInstitute.append(i)
mlInstitute.pop(0)
# Out:
# '-1'

# %%
# variables: mlCoursee, mlInstitute

# %%
# Provider:
mlprov = []
for i in soup.findAll('a',href=True, attrs={'class':'color-charcoal italic'}):
    b = str(i)
    #print(b[find_1st(b,'>')+1:find_2nd(b,'<')])
    mlprov.append(b[find_1st(b,'>')+1:find_2nd(b,'<')])

for i in mlprov:
    i = i.strip()
    mlProvider.append(i)

# %%
# variables: mlCoursee, mlInstitute, mlProvider

# %%
# rating:
mlRat = []
for d in soup.findAll('div', attrs={'class':'col border-box text-center nowrap row large-up-text-right padding-horz-small push'}):
    abc = d.find('span', attrs={'class':'xlarge-up-hidden color-charcoal text-center'})
    if abc is not None:
        #print(rating.text)
        mlRat.append(abc.text)
    else:
        mlRat.append('-1')

# %%
for i in mlRat:
    i = i.strip()
    mlRating.append(i)

# %%
# variables: mlCoursee, mlInstitute, mlProvider, mlRating

# %%
# Num of Reviews:

mlRev = []
for d in soup.findAll('div', attrs={'class':'width-100'}):
    abc = d.find('span', attrs={'class':'large-down-hidden block line-tight text-4 color-gray'})
    if abc is not None:
        #print(rating.text)
        mlRev.append(abc.text)
    else:
        mlRev.append('-1')

# %%
for i in mlRev:
    i = i.strip()
    mlReview.append(i)
    
mlReview = mlReview[7:-8]

# %%
# variables: mlCoursee, mlInstitute, mlProvider, mlRating, mlReview

# %%
# duration:

dt = []
for d in soup.findAll('div', attrs={'class':'small-down-text-2 text-3 row vert-align-middle'}):
    abc = d.find('span', attrs={'class':'hidden medium-up-inline-block small-down-text-2 text-3 large-up-margin-left-xxsmall icon-clock-charcoal icon-left'})
    if abc is not None:
        dt.append(abc.text)
    else:
        dt.append('-1')

dura = []
for i in dt:
    i = i.strip()
    #print(i)
    dura.append(i) 
    
mlDuration = []
for i in dura:
    i = ' '.join(i.split())
    i = i.replace('\n','')
    mlDuration.append(i)

# %%
# variables: mlCoursee, mlInstitute, mlProvider, mlRating, mlReview, mlDuration
# create dataframe:
dfML = pd.DataFrame({'course':mlCoursee,'ratings': mlRating,'No_of_Reviews':mlReview,
                  'provider':mlProvider, 'institute':mlInstitute, 'Duration':mlDuration})
dfML
# Out:
#                                                course ratings No_of_Reviews  \
# 0                                    Machine Learning     4.8   365 Reviews
# 1          Machine Learning for Musicians and Artists     4.9    81 Reviews
# 2   Machine Learning Foundations: A Case Study App...     3.9    39 Reviews
# 3                          Practical Machine Learning     3.4    26 Reviews
# 4              Fundamentals of Reinforcement Learning     4.9    22 Reviews
# 5                        Machine Learning: Regression     4.6    20 Reviews
# 6                   Neural Networks and Deep Learning     4.8    15 Reviews
# 7             Introduction to Machine Learning Course     3.9    19 Reviews
# 8                      Machine Learning With Big Data     1.9    14 Reviews
# 9     Machine Learning for Data Science and Analytics     3.1    15 Reviews
# 10          Aprendizaje automático y ciencia de datos     4.5    14 Reviews
# 11  Mathematics for Machine Learning: Multivariate...     4.9     9 Reviews
# 12  Prediction and Control with Function Approxima...     4.8     9 Reviews
# 13                   Machine Learning: Classification     4.8     8 Reviews
# 14                      Convolutional Neural Networks     4.9     8 Reviews
# 15  Learning from Data (Introductory Machine Learn...     4.6    10 Reviews
# 16                                   Machine Learning     4.0    11 Reviews
# 17                             Reinforcement Learning     2.9     8 Reviews
# 18                 Applied Machine Learning in Python     3.8     5 Reviews
# 19       Machine Learning: Clustering &amp; Retrieval     4.8     4 Reviews
# 20  Practical Predictive Analytics: Models and Met...     2.0     3 Reviews
# 21              Bayesian Methods for Machine Learning      -1            -1
# 22   Big Data Applications: Machine Learning at Scale      -1            -1
# 23    Applying Machine Learning to your Data with GCP      -1            -1
# 24  Improving Deep Neural Networks: Hyperparameter...     5.0     3 Reviews
# 25                                    Sequence Models     4.8     4 Reviews
# 26              Structuring Machine Learning Projects     5.0     3 Reviews
# 27  Google Cloud Platform Big Data and Machine Lea...      -1            -1
# 28                  Practical Machine Learning on H2O     1.0     1 Reviews
# 29                       Machine Learning with Python     5.0     2 Reviews
# 30  End-to-End Machine Learning with TensorFlow on...      -1            -1
# 31    Art and Science of Machine Learning auf Deutsch      -1            -1
# 32  Art and Science of Machine Learning em Portugu...      -1            -1
# 33       How Google does Machine Learning en Français      -1            -1
# 34        How Google does Machine Learning en Español      -1            -1
# 35                     Intro to TensorFlow en Español      -1            -1
# 36     Art and Science of Machine Learning en Español      -1            -1
# 37                    Intro to TensorFlow en Français      -1            -1
# 38  Google Cloud Platform Big Data and Machine Lea...      -1            -1
# 39        Fundamentals of Machine Learning in Finance     1.0     1 Reviews
# 40                Art and Science of Machine Learning      -1            -1
# 41                   How Google does Machine Learning     5.0     2 Reviews
# 42                    Launching into Machine Learning     4.0     2 Reviews
# 43                   Introduction to Machine Learning     2.0     1 Reviews
# 44               Launching into Machine Learning 日本語版      -1            -1
# 45              How Google does Machine Learning 日本語版      -1            -1
# 46  Serverless Machine Learning with Tensorflow on...      -1            -1
# 47                Production Machine Learning Systems     1.0     1 Reviews
# 48  Introduction to Deep Learning &amp; Neural Net...      -1            -1
# 49      Building Deep Learning Models with TensorFlow      -1            -1
#
#        provider                            institute  \
# 0      Coursera                  Stanford University
# 1       Kadenze     Goldsmiths, University of London
# 2      Coursera             University of Washington
# 3      Coursera             Johns Hopkins University
# 4      Coursera                University of Alberta
# 5      Coursera             University of Washington
# 6      Coursera                      deeplearning.ai
# 7       Udacity                  Stanford University
# 8      Coursera  University of California, San Diego
# 9           edX                  Columbia University
# 10          edX  Universitat Politècnica de València
# 11     Coursera              Imperial College London
# 12     Coursera                University of Alberta
# 13     Coursera             University of Washington
# 14     Coursera                      deeplearning.ai
# 15  Independent   California Institute of Technology
# 16          edX                  Columbia University
# 17      Udacity                     Brown University
# 18     Coursera               University of Michigan
# 19     Coursera             University of Washington
# 20     Coursera             University of Washington
# 21     Coursera           Higher School of Economics
# 22     Coursera                               Yandex
# 23     Coursera                         Google Cloud
# 24     Coursera                      deeplearning.ai
# 25     Coursera                      deeplearning.ai
# 26     Coursera                      deeplearning.ai
# 27     Coursera                         Google Cloud
# 28     Coursera                                  H2O
# 29     Coursera                                  IBM
# 30     Coursera                         Google Cloud
# 31     Coursera                         Google Cloud
# 32     Coursera                         Google Cloud
# 33     Coursera                         Google Cloud
# 34     Coursera                         Google Cloud
# 35     Coursera                         Google Cloud
# 36     Coursera                         Google Cloud
# 37     Coursera                         Google Cloud
# 38     Coursera                         Google Cloud
# 39     Coursera            New York University (NYU)
# 40     Coursera                         Google Cloud
# 41     Coursera                         Google Cloud
# 42     Coursera                         Google Cloud
# 43     Coursera                      Duke University
# 44     Coursera                         Google Cloud
# 45     Coursera                         Google Cloud
# 46     Coursera                         Google Cloud
# 47     Coursera                         Google Cloud
# 48     Coursera                                  IBM
# 49     Coursera                                  IBM
#
#                              Duration
# 0    5-7 hours a week , 11 weeks long
# 1                                  -1
# 2                                  -1
# 3     4-9 hours a week , 4 weeks long
# 4                                  -1
# 5                                  -1
# 6                                  -1
# 7                                  -1
# 8                                  -1
# 9    7-10 hours a week , 5 weeks long
# 10    4-5 hours a week , 5 weeks long
# 11    2-5 hours a week , 6 weeks long
# 12                                 -1
# 13                                 -1
# 14                                 -1
# 15                                 -1
# 16  8-10 hours a week , 12 weeks long
# 17                                 -1
# 18                                 -1
# 19                                 -1
# 20                                 -1
# 21      6 hours a week , 6 weeks long
# 22                                 -1
# 23    5-7 hours a week , 2 weeks long
# 24                                 -1
# 25                                 -1
# 26                                 -1
# 27   6-10 hours a week , 6 weeks long
# 28                                 -1
# 29    5-6 hours a week , 6 weeks long
# 30   8-10 hours a week , 3 weeks long
# 31    5-7 hours a week , 3 weeks long
# 32    5-7 hours a week , 3 weeks long
# 33   8-10 hours a week , 1 weeks long
# 34   8-10 hours a week , 1 weeks long
# 35   8-10 hours a week , 3 weeks long
# 36    5-7 hours a week , 3 weeks long
# 37   8-10 hours a week , 3 weeks long
# 38      3 hours a week , 6 weeks long
# 39                                 -1
# 40                                 -1
# 41   8-10 hours a week , 1 weeks long
# 42                                 -1
# 43    2-5 hours a week , 6 weeks long
# 44                                 -1
# 45   8-10 hours a week , 1 weeks long
# 46   8-12 hours a week , 1 weeks long
# 47    5-7 hours a week , 2 weeks long
# 48    2-3 hours a week , 5 weeks long
# 49                                 -1

# %%
# rating:

dfML['ratings'] = dfML['ratings'].astype(float)
MLRating = dfML.dropna()
MLRating = MLRating[MLRating.ratings != -1]
np.mean(MLRating['ratings']) # mean rating is 3.78
# Out:
# 3.8709677419354835

# %%
# Visualize overall ML Rating:

fig = px.histogram(MLRating, x="ratings")
fig.update_traces(marker_color="aqua",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='ML Ratings')
fig.show()
py.plot(fig)
# Out:
# <div>
#
#
#             <div id="dec7384a-0faf-42db-9e34-8f399714569d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dec7384a-0faf-42db-9e34-8f399714569d")) {
#                     Plotly.newPlot(
#                         'dec7384a-0faf-42db-9e34-8f399714569d',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "ratings=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "aqua", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [4.8, 4.9, 3.9, 3.4, 4.9, 4.6, 4.8, 3.9, 1.9, 3.1, 4.5, 4.9, 4.8, 4.8, 4.9, 4.6, 4.0, 2.9, 3.8, 4.8, 2.0, 5.0, 4.8, 5.0, 1.0, 5.0, 1.0, 5.0, 4.0, 2.0, 1.0], "xaxis": "x", "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...
# 'https://plotly.com/~natassha/96/'

# %%
# No.of.Reviews:
MLRating['No_of_Reviews'] = MLRating['No_of_Reviews'].str.extract('(\d+)', expand=False).astype(int)
# average no of reviews:
np.mean(MLRating['No_of_Reviews']) # 27.88
# Out:
# 23.387096774193548

# %%
# Num of Reviews- all courses
fig = px.histogram(MLRating, x="No_of_Reviews")
fig.update_traces(marker_color="aqua",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Num of Reviews')
fig.show()
py.plot(fig)
# Out:
# <div>
#
#
#             <div id="7f426cf0-15ae-49df-99ee-02f09090a0a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7f426cf0-15ae-49df-99ee-02f09090a0a3")) {
#                     Plotly.newPlot(
#                         '7f426cf0-15ae-49df-99ee-02f09090a0a3',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "No_of_Reviews=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "aqua", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [365, 81, 39, 26, 22, 20, 15, 19, 14, 15, 14, 9, 9, 8, 8, 10, 11, 8, 5, 4, 3, 3, 4, 3, 1, 2, 1, 2, 2, 1, 1], "xaxis": "x", "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...
# 'https://plotly.com/~natassha/98/'

# %%
# best courses - highest rated:

bestML = MLRating.loc[(MLRating['No_of_Reviews'] >= 5) & 
                         (MLRating['ratings'] >= 4)]
bestML = bestML.drop([10,11])

# %%
bestML
# Out:
#                                                course  ratings  No_of_Reviews  \
# 0                         Machine Learning - Stanford      4.8            365
# 1          Machine Learning for Musicians and Artists      4.9             81
# 4              Fundamentals of Reinforcement Learning      4.9             22
# 5                        Machine Learning: Regression      4.6             20
# 6                   Neural Networks and Deep Learning      4.8             15
# 12  Prediction and Control with Function Approxima...      4.8              9
# 13                   Machine Learning: Classification      4.8              8
# 14                      Convolutional Neural Networks      4.9              8
# 15  Learning from Data (Introductory Machine Learn...      4.6             10
# 16                        Machine Learning - Columbia      4.0             11
#
#        provider                           institute  \
# 0      Coursera                 Stanford University
# 1       Kadenze    Goldsmiths, University of London
# 4      Coursera               University of Alberta
# 5      Coursera            University of Washington
# 6      Coursera                     deeplearning.ai
# 12     Coursera               University of Alberta
# 13     Coursera            University of Washington
# 14     Coursera                     deeplearning.ai
# 15  Independent  California Institute of Technology
# 16          edX                 Columbia University
#
#                              Duration
# 0    5-7 hours a week , 11 weeks long
# 1                                  -1
# 4                                  -1
# 5                                  -1
# 6                                  -1
# 12                                 -1
# 13                                 -1
# 14                                 -1
# 15                                 -1
# 16  8-10 hours a week , 12 weeks long

# %%
# best ML course providers:
# pie chart:

dist = bestML['provider'].value_counts()
colors = ['mediumturquoise', 'darkorange', 'gold', 'lightgreen']
trace = go.Pie(values=(np.array(dist)),labels=dist.index)
layout = go.Layout(title='Best ML Course Provider')
data = [trace]
fig = go.Figure(trace,layout)
fig.update_traces(marker=dict(colors=colors, line=dict(color='#000000', width=2)))
fig.show() 
py.plot(fig)
# Out:
# <div>
#
#
#             <div id="fe01b918-3eaf-40bd-af6a-a6b15e090dbd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fe01b918-3eaf-40bd-af6a-a6b15e090dbd")) {
#                     Plotly.newPlot(
#                         'fe01b918-3eaf-40bd-af6a-a6b15e090dbd',
#                         [{"labels": ["Coursera", "edX", "Independent", "Kadenze"], "marker": {"colors": ["mediumturquoise", "darkorange", "gold", "lightgreen"], "line": {"color": "#000000", "width": 2}}, "type": "pie", "values": [7, 1, 1, 1]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...
# 'https://plotly.com/~natassha/104/'

# %%
# best rated ML institute counts:

institute_count= pd.DataFrame({'institute':bestML["institute"].value_counts().index, 'counts':bestML["institute"].value_counts().values}).sort_values("counts")
fig = px.bar(institute_count, x='institute', y='counts')
fig.update_traces(marker_color="aqua",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Best Rated ML Institute')
py.plot(fig)
fig.show()
# Out:
# <div>
#
#
#             <div id="02a4327b-790e-4d9b-838a-c48373c160c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("02a4327b-790e-4d9b-838a-c48373c160c6")) {
#                     Plotly.newPlot(
#                         '02a4327b-790e-4d9b-838a-c48373c160c6',
#                         [{"alignmentgroup": "True", "hovertemplate": "institute=%{x}<br>counts=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "aqua", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["California Institute of Technology", "Columbia University", "Goldsmiths, University of London", "Stanford University", "University of Alberta", "deeplearning.ai", "University of Washington"], "xaxis": "x", "y": [1, 1, 1, 1, 2, 2, 2], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %%
# Best Rated Courses:

bestML.loc[0,'course'] = 'Machine Learning - Stanford'
bestML.loc[16,'course'] = 'Machine Learning - Columbia'

fig = px.bar(bestML, x='course', y='ratings')
fig.update_traces(marker_color="aqua",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Highest Rated ML Courses')
py.plot(fig)
fig.show()
# Out:
# <div>
#
#
#             <div id="54121a5d-a47c-4286-aaf9-65b63b32453a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("54121a5d-a47c-4286-aaf9-65b63b32453a")) {
#                     Plotly.newPlot(
#                         '54121a5d-a47c-4286-aaf9-65b63b32453a',
#                         [{"alignmentgroup": "True", "hovertemplate": "course=%{x}<br>ratings=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "aqua", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Machine Learning - Stanford", "Machine Learning for Musicians and Artists", "Fundamentals of Reinforcement Learning", "Machine Learning: Regression", "Neural Networks and Deep Learning", "Prediction and Control with Function Approximation", "Machine Learning: Classification", "Convolutional Neural Networks", "Learning from Data (Introductory Machine Learning course)", "Machine Learning - Columbia"], "xaxis": "x", "y": [4.8, 4.9, 4.9, 4.6, 4.8, 4.8, 4.8, 4.9, 4.6, 4.0], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %%
# Best Courses & Num of Reviews

fig = px.bar(bestML, x='course', y='No_of_Reviews')
fig.update_traces(marker_color="aqua",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Best Course Num of Reviews')
py.plot(fig)
fig.show()
# Out:
# <div>
#
#
#             <div id="07532450-2a34-4178-a7f5-9ca3af209e34" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("07532450-2a34-4178-a7f5-9ca3af209e34")) {
#                     Plotly.newPlot(
#                         '07532450-2a34-4178-a7f5-9ca3af209e34',
#                         [{"alignmentgroup": "True", "hovertemplate": "course=%{x}<br>No_of_Reviews=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "aqua", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Machine Learning - Stanford", "Machine Learning for Musicians and Artists", "Fundamentals of Reinforcement Learning", "Machine Learning: Regression", "Neural Networks and Deep Learning", "Prediction and Control with Function Approximation", "Machine Learning: Classification", "Convolutional Neural Networks", "Learning from Data (Introductory Machine Learning course)", "Machine Learning - Columbia"], "xaxis": "x", "y": [365, 81, 22, 20, 15, 9, 8, 8, 10, 11], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %%
# Python Programming Courses

driver.get('https://www.classcentral.com/subject/python')

# %%
content = driver.page_source
soup = BeautifulSoup(content)

pythonCourse = []
pythonInstitute = []
pythonProvider = []
pythonRating = []
pythonReview = []

# %%
for i in soup.findAll("span",{'class' : 'text-1 weight-semi line-tight'}):
    b = str(i)
   # print(b[find_1st(b,'>')+1:find_2nd(b,'<')])
    pythonCourse.append(b[find_1st(b,'>')+1:find_2nd(b,'<')])
b = []
for d in soup.findAll('a', attrs={'class':'color-charcoal block line-tight course-name'}):
    abc = d.find('span', attrs={'class':'text-1 weight-semi line-tight'})
    if abc is not None:
        #print(rating.text)
        b.append(abc.text)
    else:
        b.append('-1')

# %%
pythonCoursee = []
for i in pythonCourse:
    i = i.strip()
   # print(i)
    pythonCoursee.append(i)

# %%
nnnn = []
for d in soup.findAll('div', attrs={'class':'truncate'}):
    abc = d.find('a', attrs={'class':'color-charcoal small-down-text-2 text-3'})
    if abc is not None:
        #print(rating.text)
        nnnn.append(abc.text)
    else:
        nnnn.append('-1')

# %%
nnnn.pop(0)

for i in nnnn:
    i = i.strip()
 #   print(i)
    pythonInstitute.append(i)

# %%
# pythonCoursee, pythonInstitute

# %%
# provider:

for i in soup.findAll('a',href=True, attrs={'class':'color-charcoal italic'}):
    b = str(i)
  #  print(b[find_1st(b,'>')+1:find_2nd(b,'<')])
    pythonProvider.append(b[find_1st(b,'>')+1:find_2nd(b,'<')])

# %%
pythonProviderr = []
for i in pythonProvider:
    i = i.strip()
   # print(i)
    pythonProviderr.append(i)

# %%
# rating:
r = []
for d in soup.findAll('div', attrs={'class':'col border-box text-center nowrap row large-up-text-right padding-horz-small push'}):
    abc = d.find('span', attrs={'class':'xlarge-up-hidden color-charcoal text-center'})
    if abc is not None:
        #print(rating.text)
        r.append(abc.text)
    else:
        r.append('-1')
pythonRating = []
for i in r:
    i = i.strip()
   # print(i)
    pythonRating.append(i)

# %%
# review:
ab = []
for d in soup.findAll('div', attrs={'class':'width-100'}):
    abc = d.find('span', attrs={'class':'large-down-hidden block line-tight text-4 color-gray'})
    if abc is not None:  
        ab.append(abc.text)
    else:
        ab.append('-1')

# %%
ab = ab[7:-8]
ab.pop(5)
# Out:
# '-1'

# %%
pythonReview = []
for i in ab:
    i = i.strip()
    #print(i)
    pythonReview.append(i)

# %%
# Duration:

du = []
for d in soup.findAll('div', attrs={'class':'small-down-text-2 text-3 row vert-align-middle'}):
    abc = d.find('span', attrs={'class':'hidden medium-up-inline-block small-down-text-2 text-3 large-up-margin-left-xxsmall icon-clock-charcoal icon-left'})
    if abc is not None:
        du.append(abc.text)
    else:
        du.append('-1')

pydur = []
for i in du:
    i = i.strip()
    #print(i)
    pydur.append(i) 
    
pythonDuration = []
for i in pydur:
    i = ' '.join(i.split())
    i = i.replace('\n','')
    pythonDuration.append(i)

# %%
# variables: pythonCoursee, pythonInstitute, pythonProviderr, pythonRating, pythonReview, pythonDuration
# create dataframe:

dfPython = pd.DataFrame({'course':pythonCoursee,'ratings': pythonRating,'No_of_Reviews':pythonReview,
                  'provider':pythonProviderr, 'institute':pythonInstitute, 'Duration':pythonDuration})
dfPython
# Out:
#                                                course ratings  No_of_Reviews  \
# 0   Programming for Everybody (Getting Started wit...     4.9  17155 Reviews
# 1                              Python Data Structures     4.9   6676 Reviews
# 2   An Introduction to Interactive Programming in ...     4.9   3219 Reviews
# 3                     Using Python to Access Web Data     4.7   2567 Reviews
# 4                         Using Databases with Python     4.7   2046 Reviews
# 5                                Python for Everybody     4.9    301 Reviews
# 6        Python and Statistics for Financial Analysis     4.3    137 Reviews
# 7   Computing in Python I: Fundamentals and Proced...     4.8    105 Reviews
# 8                  Learn to Program: The Fundamentals     4.8    105 Reviews
# 9   An Introduction to Interactive Programming in ...     4.8     55 Reviews
# 10   Computing in Python IV: Objects &amp; Algorithms     4.9     47 Reviews
# 11                            Python for Data Science     4.4     39 Reviews
# 12         Computing in Python II: Control Structures     4.9     34 Reviews
# 13       Python for Everybody - Exploring Information     4.9     33 Reviews
# 14                   Principles of Computing (Part 1)     4.6     31 Reviews
# 15          Hadoop Platform and Application Framework     1.9     25 Reviews
# 16             Introduction to Data Science in Python     2.5     44 Reviews
# 17           Computing in Python III: Data Structures     4.8     24 Reviews
# 18  Machine Learning Foundations: A Case Study App...     3.9     39 Reviews
# 19               Artificial Intelligence for Robotics     4.8     23 Reviews
# 20                   Principles of Computing (Part 2)     4.4     16 Reviews
# 21                      Algorithmic Thinking (Part 1)     4.1     15 Reviews
# 22                       Machine Learning for Trading     3.1     15 Reviews
# 23                        Design of Computer Programs     4.1     14 Reviews
# 24                              Intro to Data Science     4.2     13 Reviews
# 25                   Intro to Python for Data Science     4.3     13 Reviews
# 26                              Programming Languages     3.4     10 Reviews
# 27                             Full Stack Foundations     3.1     10 Reviews
# 28                       Python: Aprender a programar     2.9     10 Reviews
# 29                      Algorithmic Thinking (Part 2)     4.4      9 Reviews
# 30  CS50's Web Programming with Python and JavaScript     4.6      9 Reviews
# 31                       Machine Learning: Regression     4.6     20 Reviews
# 32  Machine Learning (aprendizaje automático) con ...      -1             -1
# 33             Математика и Python для анализа данных     4.0      4 Reviews
# 34                  Основы программирования на Python      -1             -1
# 35                      Python Programming Essentials     5.0      1 Reviews
# 36                        Python Data Representations      -1             -1
# 37                               Python Data Analysis      -1             -1
# 38                          Python Data Visualization      -1             -1
# 39  用 Python 做商管程式設計（二）(Programming for Business C...      -1             -1
# 40                          Python для анализа данных      -1             -1
# 41                                Погружение в Python      -1             -1
# 42          Python Functions, Files, and Dictionaries      -1             -1
# 43                                      Python Basics      -1             -1
# 44         Data Collection and Processing with Python      -1             -1
# 45       Inferential Statistical Analysis with Python      -1             -1
# 46     Understanding and Visualizing Data with Python      -1             -1
# 47  Python and Machine-Learning for Asset Manageme...      -1             -1
# 48  Introduction to Computer Vision with Watson an...      -1             -1
# 49  Advanced Portfolio Construction and Analysis w...      -1             -1
#
#        provider                                          institute  \
# 0      Coursera                             University of Michigan
# 1      Coursera                             University of Michigan
# 2      Coursera                                    Rice University
# 3      Coursera                             University of Michigan
# 4      Coursera                             University of Michigan
# 5      Coursera                             University of Michigan
# 6      Coursera  The Hong Kong University of Science and Techno...
# 7           edX                    Georgia Institute of Technology
# 8      Coursera                              University of Toronto
# 9      Coursera                                    Rice University
# 10          edX                    Georgia Institute of Technology
# 11       Swayam              Indian Institute of Technology Madras
# 12          edX                    Georgia Institute of Technology
# 13  Independent                                                 -1
# 14     Coursera                                    Rice University
# 15     Coursera                University of California, San Diego
# 16     Coursera                             University of Michigan
# 17          edX                    Georgia Institute of Technology
# 18     Coursera                           University of Washington
# 19      Udacity                                Stanford University
# 20     Coursera                                    Rice University
# 21     Coursera                                    Rice University
# 22      Udacity                    Georgia Institute of Technology
# 23      Udacity                                Stanford University
# 24      Udacity                                                 -1
# 25     Datacamp                                                 -1
# 26      Udacity                             University of Virginia
# 27      Udacity                                                 -1
# 28          edX                Universitat Politècnica de València
# 29     Coursera                                    Rice University
# 30          edX                                 Harvard University
# 31     Coursera                           University of Washington
# 32          edX                                                IBM
# 33     Coursera         Moscow Institute of Physics and Technology
# 34     Coursera                         Higher School of Economics
# 35     Coursera                                    Rice University
# 36     Coursera                                    Rice University
# 37     Coursera                                    Rice University
# 38     Coursera                                    Rice University
# 39     Coursera                         National Taiwan University
# 40     Coursera         Moscow Institute of Physics and Technology
# 41     Coursera         Moscow Institute of Physics and Technology
# 42     Coursera                             University of Michigan
# 43     Coursera                             University of Michigan
# 44     Coursera                             University of Michigan
# 45     Coursera                             University of Michigan
# 46     Coursera                             University of Michigan
# 47     Coursera                              EDHEC Business School
# 48     Coursera                                                IBM
# 49     Coursera                              EDHEC Business School
#
#                             Duration
# 0                                 -1
# 1                                 -1
# 2   7-10 hours a week , 5 weeks long
# 3                                 -1
# 4                                 -1
# 5    12 hours a week , 17 weeks long
# 6    3-4 hours a week , 4 weeks long
# 7   9-10 hours a week , 5 weeks long
# 8    6-8 hours a week , 7 weeks long
# 9   7-10 hours a week , 4 weeks long
# 10  9-10 hours a week , 5 weeks long
# 11                                -1
# 12  9-10 hours a week , 5 weeks long
# 13                                -1
# 14  7-10 hours a week , 5 weeks long
# 15                                -1
# 16                                -1
# 17  9-10 hours a week , 5 weeks long
# 18                                -1
# 19                                -1
# 20  7-10 hours a week , 4 weeks long
# 21  7-10 hours a week , 4 weeks long
# 22                                -1
# 23                                -1
# 24                                -1
# 25                                -1
# 26                                -1
# 27                                -1
# 28   3-4 hours a week , 8 weeks long
# 29  7-10 hours a week , 4 weeks long
# 30  6-9 hours a week , 12 weeks long
# 31                                -1
# 32   4-6 hours a week , 5 weeks long
# 33                                -1
# 34                                -1
# 35   5-7 hours a week , 4 weeks long
# 36   5-7 hours a week , 4 weeks long
# 37   5-7 hours a week , 4 weeks long
# 38   5-7 hours a week , 4 weeks long
# 39                                -1
# 40   7-9 hours a week , 6 weeks long
# 41   5-7 hours a week , 6 weeks long
# 42                                -1
# 43                                -1
# 44                                -1
# 45   4-6 hours a week , 4 weeks long
# 46   4-6 hours a week , 4 weeks long
# 47     2 hours a week , 4 weeks long
# 48   3-4 hours a week , 4 weeks long
# 49   3-4 hours a week , 4 weeks long

# %%
# rating:

dfPython['ratings'] = dfPython['ratings'].astype(float)
pyRating = dfPython.dropna()
pyRating = pyRating[pyRating.ratings != -1]
np.mean(pyRating['ratings']) # mean rating: 4.113
# Out:
# 4.279411764705881

# %%
# visualize overall rating:


fig = px.histogram(pyRating, x="ratings")
fig.update_traces(marker_color="indianred",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Python Ratings')
fig.show()
py.plot(fig)
# Out:
# <div>
#
#
#             <div id="0e02934f-6554-4777-83dc-de05eaf79ccf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0e02934f-6554-4777-83dc-de05eaf79ccf")) {
#                     Plotly.newPlot(
#                         '0e02934f-6554-4777-83dc-de05eaf79ccf',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "ratings=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "indianred", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [4.9, 4.9, 4.9, 4.7, 4.7, 4.9, 4.3, 4.8, 4.8, 4.8, 4.9, 4.4, 4.9, 4.9, 4.6, 1.9, 2.5, 4.8, 3.9, 4.8, 4.4, 4.1, 3.1, 4.1, 4.2, 4.3, 3.4, 3.1, 2.9, 4.4, 4.6, 4.6, 4.0, 5.0], "xaxis": "x", "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...
# 'temp-plot.html'

# %%
# No.of.Reviews:
pyRating['No_of_Reviews'] = pyRating['No_of_Reviews'].str.extract('(\d+)', expand=False).astype(int)
# average no of reviews:
np.mean(pyRating['No_of_Reviews']) # 725.9
# Out:
# 966.5882352941177

# %%
# !pip install chart_studio
# Out:
# Requirement already satisfied: chart_studio in c:\programdata\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from chart_studio) (1.14.0)
# Requirement already satisfied: plotly in c:\programdata\anaconda3\lib\site-packages (from chart_studio) (4.8.2)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from chart_studio) (2.22.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\programdata\anaconda3\lib\site-packages (from chart_studio) (1.3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->chart_studio) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->chart_studio) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->chart_studio) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->chart_studio) (3.0.4)

# %%
# Imports:
import chart_studio
username = 'natassha' 
api_key = 'mkbM2OeSreIbCanb6xUI' 
chart_studio.tools.set_credentials_file(username=username, api_key=api_key)
import chart_studio.plotly as py

# %%
# Visualize no.of.reviews:
# Num of Reviews- all courses
fig = px.histogram(pyRating, x="No_of_Reviews")
fig.update_traces(marker_color="indianred",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Num of Reviews') # outliers: some very highly rated courses, distribution is right skewed
fig.show()
#py.plot(fig)
# Out:
# <div>
#
#
#             <div id="db4e08a6-a6bb-41a9-b257-6449d5c4efda" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("db4e08a6-a6bb-41a9-b257-6449d5c4efda")) {
#                     Plotly.newPlot(
#                         'db4e08a6-a6bb-41a9-b257-6449d5c4efda',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "No_of_Reviews=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "indianred", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [17155, 6676, 3219, 2567, 2046, 301, 137, 105, 105, 55, 47, 39, 34, 33, 31, 25, 44, 24, 39, 23, 16, 15, 15, 14, 13, 13, 10, 10, 10, 9, 9, 20, 4, 1], "xaxis": "x", "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %%
# best courses - highest rated:

bestPython = pyRating.loc[(pyRating['No_of_Reviews'] >= 50) & 
                         (pyRating['ratings'] >= 4.5)]

# %%
bestPython
# Out:
#                                               course  ratings  No_of_Reviews  \
# 0  Programming for Everybody (Getting Started wit...      4.9          17155
# 1                             Python Data Structures      4.9           6676
# 2  An Introduction to Interactive Programming in ...      4.9           3219
# 3                    Using Python to Access Web Data      4.7           2567
# 4                        Using Databases with Python      4.7           2046
# 5                               Python for Everybody      4.9            301
# 7  Computing in Python I: Fundamentals and Proced...      4.8            105
# 8                 Learn to Program: The Fundamentals      4.8            105
# 9  An Introduction to Interactive Programming in ...      4.8             55
#
#    provider                        institute                          Duration
# 0  Coursera           University of Michigan                                -1
# 1  Coursera           University of Michigan                                -1
# 2  Coursera                  Rice University  7-10 hours a week , 5 weeks long
# 3  Coursera           University of Michigan                                -1
# 4  Coursera           University of Michigan                                -1
# 5  Coursera           University of Michigan   12 hours a week , 17 weeks long
# 7       edX  Georgia Institute of Technology  9-10 hours a week , 5 weeks long
# 8  Coursera            University of Toronto   6-8 hours a week , 7 weeks long
# 9  Coursera                  Rice University  7-10 hours a week , 4 weeks long

# %%
# best rated Python course providers:
# pie chart:

dist = bestPython['provider'].value_counts()
colors = ['mediumturquoise', 'darkorange', 'gold', 'lightgreen']
trace = go.Pie(values=(np.array(dist)),labels=dist.index)
layout = go.Layout(title='Best Rated Python Course Provider')
data = [trace]
fig = go.Figure(trace,layout)
fig.update_traces(marker=dict(colors=colors, line=dict(color='#000000', width=2)))
fig.show() 
py.plot(fig)
# Out:
# <div>
#
#
#             <div id="56e0d55a-5b9e-44c9-a69e-49d411248da6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("56e0d55a-5b9e-44c9-a69e-49d411248da6")) {
#                     Plotly.newPlot(
#                         '56e0d55a-5b9e-44c9-a69e-49d411248da6',
#                         [{"labels": ["Coursera", "edX"], "marker": {"colors": ["mediumturquoise", "darkorange", "gold", "lightgreen"], "line": {"color": "#000000", "width": 2}}, "type": "pie", "values": [8, 1]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...
# 'https://plotly.com/~natassha/58/'

# %%
# best rated DS institute counts:

institute_count= pd.DataFrame({'institute':bestPython["institute"].value_counts().index, 'counts':bestPython["institute"].value_counts().values}).sort_values("counts")
fig = px.bar(institute_count, x='institute', y='counts')
fig.update_traces(marker_color="indianred",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Best Rated Python Institute')
py.plot(fig)
fig.show()
# Out:
# <div>
#
#
#             <div id="e2932c50-0e53-4924-98c5-223813f833b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e2932c50-0e53-4924-98c5-223813f833b1")) {
#                     Plotly.newPlot(
#                         'e2932c50-0e53-4924-98c5-223813f833b1',
#                         [{"alignmentgroup": "True", "hovertemplate": "institute=%{x}<br>counts=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "indianred", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Georgia Institute of Technology", "University of Toronto", "Rice University", "University of Michigan"], "xaxis": "x", "y": [1, 1, 2, 5], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %%
# Best Rated Courses:

fig = px.bar(bestPython, x='course', y='ratings')
fig.update_traces(marker_color="indianred",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Highest Rated Python Courses')
py.plot(fig)
fig.show()
# Out:
# <div>
#
#
#             <div id="bebab924-cd01-4a6c-bd19-2b5a5a344b35" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bebab924-cd01-4a6c-bd19-2b5a5a344b35")) {
#                     Plotly.newPlot(
#                         'bebab924-cd01-4a6c-bd19-2b5a5a344b35',
#                         [{"alignmentgroup": "True", "hovertemplate": "course=%{x}<br>ratings=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "indianred", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Programming for Everybody (Getting Started with Python)", "Python Data Structures", "An Introduction to Interactive Programming in Python (Part 1)", "Using Python to Access Web Data", "Using Databases with Python", "Python for Everybody", "Computing in Python I: Fundamentals and Procedural Programming", "Learn to Program: The Fundamentals", "An Introduction to Interactive Programming in Python (Part 2)"], "xaxis": "x", "y": [4.9, 4.9, 4.9, 4.7, 4.7, 4.9, 4.8, 4.8, 4.8], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %%
# Best Courses & Num of Reviews

fig = px.bar(bestPython, x='course', y='No_of_Reviews')
fig.update_traces(marker_color="indianred",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Best Python Courses: Num of Reviews')
py.plot(fig)
fig.show()
# Out:
# <div>
#
#
#             <div id="88bca1d8-0562-4396-9947-a289bbd3e5cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("88bca1d8-0562-4396-9947-a289bbd3e5cb")) {
#                     Plotly.newPlot(
#                         '88bca1d8-0562-4396-9947-a289bbd3e5cb',
#                         [{"alignmentgroup": "True", "hovertemplate": "course=%{x}<br>No_of_Reviews=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "indianred", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Programming for Everybody (Getting Started with Python)", "Python Data Structures", "An Introduction to Interactive Programming in Python (Part 1)", "Using Python to Access Web Data", "Using Databases with Python", "Python for Everybody", "Computing in Python I: Fundamentals and Procedural Programming", "Learn to Program: The Fundamentals", "An Introduction to Interactive Programming in Python (Part 2)"], "xaxis": "x", "y": [17155, 6676, 3219, 2567, 2046, 301, 105, 105, 55], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %%
# R Programming Courses:

# %%
driver.get('https://www.classcentral.com/search?q=r+programming')
content = driver.page_source
soup = BeautifulSoup(content)

# %%
rCourse = []
rInstitute = []
rProvider = []
rRating = []
rReview = []
rDuration = []
for i in soup.findAll("span",{'class' : 'text-1 weight-semi line-tight'}):
    b = str(i)
   # print(b[find_1st(b,'>')+1:find_2nd(b,'<')])
    rCourse.append(b[find_1st(b,'>')+1:find_2nd(b,'<')])

# %%
rCoursee = []
for i in rCourse:
    i = i.strip()
   # print(i)
    rCoursee.append(i)

# %%
# Institute:
r = []
for d in soup.findAll('div', attrs={'class':'truncate'}):
    abc = d.find('a', attrs={'class':'color-charcoal small-down-text-2 text-3'})
    if abc is not None:
        #print(rating.text)
        r.append(abc.text)
    else:
        r.append('-1')
for i in r:
    i = i.strip()
    #print(i)
    rInstitute.append(i)

# %%
# Variables : rCoursee, rInstitute

# %%
# Provider
for i in soup.findAll('a',href=True, attrs={'class':'color-charcoal italic'}):
    b = str(i)
   # print(b[find_1st(b,'>')+1:find_2nd(b,'<')])
    rProvider.append(b[find_1st(b,'>')+1:find_2nd(b,'<')])

# %%
rProviderr = []
for i in rProvider:
    i = i.strip()
    #print(i)
    rProviderr.append(i)

# %%
# rating:
rr = []
for d in soup.findAll('div', attrs={'class':'col border-box text-center nowrap row large-up-text-right padding-horz-small push'}):
    abc = d.find('span', attrs={'class':'xlarge-up-hidden color-charcoal text-center'})
    if abc is not None:
        #print(rating.text)
        rr.append(abc.text)
    else:
        rr.append('-1')
for i in rr:
    i = i.strip()
    #print(i)
    rRating.append(i)

# %%
# Variables: rCoursee, rProviderr, rInstitute, rRating

# %%
# Review:
rev = []
for d in soup.findAll('div', attrs={'class':'width-100'}):
    abc = d.find('span', attrs={'class':'large-down-hidden block line-tight text-4 color-gray'})
    if abc is not None:
        
        rev.append(abc.text)
    else:
        rev.append('-1')
rev = rev[5:-8]
for i in rev:
    i = i.strip()
    #print(i)
    rReview.append(i)

# %%
# Variables: rCoursee, rProviderr, rInstitute, rRating, rReview

# %%
# Duration:
# duration:

rt = []
for d in soup.findAll('div', attrs={'class':'small-down-text-2 text-3 row vert-align-middle'}):
    abc = d.find('span', attrs={'class':'hidden medium-up-inline-block small-down-text-2 text-3 large-up-margin-left-xxsmall icon-clock-charcoal icon-left'})
    if abc is not None:
        rt.append(abc.text)
    else:
        rt.append('-1')

rdur = []
for i in rt:
    i = i.strip()
    #print(i)
    rdur.append(i) 
    
for i in rdur:
    i = ' '.join(i.split())
    i = i.replace('\n','')
    rDuration.append(i)

# %%
# Variables: rCoursee, rProviderr, rInstitute, rRating, rReview, rDuration
# create duration:
dfR = pd.DataFrame({'course':rCoursee,'ratings': rRating,'No_of_Reviews':rReview,
                  'provider':rProviderr, 'institute':rInstitute, 'Duration':rDuration})
dfR
# Out:
#                                                course ratings No_of_Reviews  \
# 0                              Advanced R Programming     4.0     1 Reviews
# 1                                       R Programming     2.7   243 Reviews
# 2                       The R Programming Environment     2.8     4 Reviews
# 3   Advanced Linear Models for Data Science 1: Lea...     5.0     1 Reviews
# 4   Introduction to Real-Time Audio Programming in...     5.0    34 Reviews
# 5                                Data Analysis with R     4.6    18 Reviews
# 6                   Introduction to Neurohacking In R      -1            -1
# 7                  Introduction to R for Data Science     4.2    28 Reviews
# 8    Introduction to Linear Models and Matrix Algebra     4.4    11 Reviews
# 9                                 Building R Packages     3.0     2 Reviews
# 10                             Data Science: R Basics     4.6    10 Reviews
# 11                         Data Science for Engineers     1.0     1 Reviews
# 12                                Bayesian Statistics     2.7    12 Reviews
# 13                   Financial Risk Management with R      -1            -1
# 14                                  Introduction to R     3.8    12 Reviews
# 15                 Introduction to R for Data Science     5.0     1 Reviews
# 16                                   Introducción a R      -1            -1
# 17                 Foundations of marketing analytics     5.0     1 Reviews
# 18                                   Statistics and R     3.5    20 Reviews
# 19                          Dealing With Missing Data      -1            -1
# 20               Combining and Analyzing Complex Data      -1            -1
# 21  The Caltech-JPL Summer School on Big Data Anal...     5.0     2 Reviews
# 22                          Смешанные линейные модели      -1            -1
# 23                Знакомство с R и базовая статистика      -1            -1
# 24  Build a Deep Learning Based Image Classifier w...      -1            -1
# 25  Advanced Linear Models for Data Science 2: Sta...     5.0     1 Reviews
# 26  Predicting Salaries with Simple Linear Regress...      -1            -1
# 27                              Graphing with ggplot2      -1            -1
# 28  Introducción a Data Science: Programación Esta...     4.0     2 Reviews
# 29  Predict Housing Prices in R on Boston Housing ...      -1            -1
# 30  Predict Ideal Diamonds over Good Diamonds usin...      -1            -1
# 31  Create Technical Stock Charts Using R and Quan...      -1            -1
# 32  Machine Learning:  Predict Poisonous Mushrooms...      -1            -1
# 33    Analyze Stock Data using R and Quantmod Package      -1            -1
# 34  Data Analytics:  Scraping Data using Hadley Wi...      -1            -1
# 35     Build Random Forests in R with Azure ML Studio      -1            -1
# 36              Introduction to Clinical Data Science      -1            -1
# 37                        Social Media Data Analytics     3.5     2 Reviews
# 38                Análisis Estadístico de datos con R     1.0     1 Reviews
# 39      Designing, Running, and Analyzing Experiments     1.5     2 Reviews
# 40         Logistic Regression in R for Public Health      -1            -1
# 41                         Statistics with R Capstone      -1            -1
# 42                     Advanced Data Mining with Weka     5.0     2 Reviews
# 43  Introduction to Statistics &amp; Data Analysis...      -1            -1
# 44                          Explore Statistics with R     3.7    14 Reviews
# 45             Exploratory Multivariate Data Analysis     5.0     1 Reviews
# 46                         Data Processing with Azure      -1            -1
# 47  Introduction to Computational Finance and Fina...     3.5    11 Reviews
# 48                       Statistics for Business - II     5.0     2 Reviews
# 49           Linear Regression in R for Public Health      -1            -1
#
#                        provider                                 institute  \
# 0                      Coursera                  Johns Hopkins University
# 1                      Coursera                  Johns Hopkins University
# 2                      Coursera                  Johns Hopkins University
# 3                      Coursera                  Johns Hopkins University
# 4                       Kadenze          California Institute of the Arts
# 5                       Udacity                                  Facebook
# 6                      Coursera                  Johns Hopkins University
# 7                           edX                                 Microsoft
# 8                           edX                        Harvard University
# 9                      Coursera                  Johns Hopkins University
# 10                          edX                        Harvard University
# 11                       Swayam     Indian Institute of Technology Madras
# 12                     Coursera                           Duke University
# 13                     Coursera                           Duke University
# 14                     Datacamp                                        -1
# 15                  FutureLearn                         Purdue University
# 16                          edX                       Universidad Anáhuac
# 17                     Coursera                     ESSEC Business School
# 18                          edX                        Harvard University
# 19                     Coursera      University of Maryland, College Park
# 20                     Coursera      University of Maryland, College Park
# 21                     Coursera        California Institute of Technology
# 22                     Coursera         Saint Petersburg State University
# 23                     Coursera         Saint Petersburg State University
# 24                     Coursera                  Coursera Project Network
# 25                     Coursera                  Johns Hopkins University
# 26                     Coursera                  Coursera Project Network
# 27                     Coursera                  Coursera Project Network
# 28                     Coursera   Universidad Nacional Autónoma de México
# 29                     Coursera                  Coursera Project Network
# 30                     Coursera                  Coursera Project Network
# 31                     Coursera                  Coursera Project Network
# 32                     Coursera                  Coursera Project Network
# 33                     Coursera                  Coursera Project Network
# 34                     Coursera                  Coursera Project Network
# 35                     Coursera                  Coursera Project Network
# 36                     Coursera             University of Colorado System
# 37                     Coursera                        Rutgers University
# 38                     Miríadax            Universidad Católica de Murcia
# 39                     Coursera       University of California, San Diego
# 40                     Coursera                   Imperial College London
# 41                     Coursera                           Duke University
# 42                  Independent                     University of Waikato
# 43                     Coursera                   Imperial College London
# 44                          edX                     Karolinska Institutet
# 45  France Université Numerique                          Agrocampus Ouest
# 46                     Coursera                                LearnQuest
# 47                     Coursera                  University of Washington
# 48                          edX  Indian Institute of Management Bangalore
# 49                     Coursera                   Imperial College London
#
#                                      Duration
# 0                                          -1
# 1             7-9 hours a week , 4 weeks long
# 2                                          -1
# 3                                          -1
# 4                                          -1
# 5                                          -1
# 6                                          -1
# 7             2-3 hours a week , 4 weeks long
# 8             2-4 hours a week , 4 weeks long
# 9                                          -1
# 10            1-2 hours a week , 8 weeks long
# 11                                         -1
# 12                                         -1
# 13             14 hours a week , 4 weeks long
# 14                                         -1
# 15              4 hours a week , 4 weeks long
# 16            5-8 hours a week , 4 weeks long
# 17                                         -1
# 18            2-4 hours a week , 4 weeks long
# 19                                         -1
# 20                                         -1
# 21          20-25 hours a week , 2 weeks long
# 22              9 hours a week , 4 weeks long
# 23                                         -1
# 24              1 hours a week , 1 weeks long
# 25                                         -1
# 26              2 hours a week , 1 weeks long
# 27              4 hours a week , 1 weeks long
# 28                                         -1
# 29              2 hours a week , 1 weeks long
# 30              2 hours a week , 1 weeks long
# 31              2 hours a week , 1 weeks long
# 32              2 hours a week , 1 weeks long
# 33              2 hours a week , 1 weeks long
# 34              2 hours a week , 1 weeks long
# 35              4 hours a week , 1 weeks long
# 36            1-3 hours a week , 4 weeks long
# 37                                         -1
# 38                                         -1
# 39                                         -1
# 40            3-5 hours a week , 4 weeks long
# 41           5-10 hours a week , 8 weeks long
# 42                                         -1
# 43            2-5 hours a week , 4 weeks long
# 44                                         -1
# 45              5 hours a week , 5 weeks long
# 46  13 hours worth of material , 3 weeks long
# 47                                         -1
# 48            2-4 hours a week , 7 weeks long
# 49            3-5 hours a week , 4 weeks long

# %%
# Rating:
import numpy as np
dfR['ratings'] = dfR['ratings'].astype(float)
rRating = dfR.dropna()
rRating = rRating[rRating.ratings != -1]
np.mean(rRating['ratings']) # mean rating is 3.75
# Out:
# 3.833333333333334

# %%
# Visualize overall ratings
fig = px.histogram(rRating, x="ratings")
fig.update_traces(marker_color="darkred",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='R Course Ratings')
fig.show()
#py.plot(fig)
# Out:
# <div>
#
#
#             <div id="aa9c9fe4-b71b-44fb-849b-10659aff07c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("aa9c9fe4-b71b-44fb-849b-10659aff07c5")) {
#                     Plotly.newPlot(
#                         'aa9c9fe4-b71b-44fb-849b-10659aff07c5',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "ratings=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "darkred", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [4.0, 2.7, 2.8, 5.0, 5.0, 4.6, 4.2, 4.4, 3.0, 4.6, 1.0, 2.7, 3.8, 5.0, 5.0, 3.5, 5.0, 5.0, 4.0, 3.5, 1.0, 1.5, 5.0, 3.7, 5.0, 3.5, 5.0], "xaxis": "x", "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %%
# No.of.Reviews:

rRating['No_of_Reviews'] = rRating['No_of_Reviews'].str.extract('(\d+)', expand=False).astype(int)
np.mean(rRating['No_of_Reviews']) # mean num of reviews: 17.71
# Out:
# 16.25925925925926

# %%
# All course review num
fig = px.histogram(rRating, x="No_of_Reviews")
fig.update_traces(marker_color="darkred",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Num of Reviews')
fig.show()
py.plot(fig)
# Out:
# <div>
#
#
#             <div id="0aea4c74-0dc2-4c99-a454-04c5f8154a32" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0aea4c74-0dc2-4c99-a454-04c5f8154a32")) {
#                     Plotly.newPlot(
#                         '0aea4c74-0dc2-4c99-a454-04c5f8154a32',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "No_of_Reviews=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "darkred", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [1, 243, 4, 1, 34, 18, 28, 11, 2, 10, 1, 12, 12, 1, 1, 20, 2, 1, 2, 2, 1, 2, 2, 14, 1, 11, 2], "xaxis": "x", "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...
# 'https://plotly.com/~natassha/110/'

# %%
# best R courses:
bestR = rRating.loc[(rRating['No_of_Reviews'] >= 10) & 
                         (rRating['ratings'] >= 3.5)]
bestR
# Out:
#                                                course  ratings  No_of_Reviews  \
# 4   Introduction to Real-Time Audio Programming in...      5.0             34
# 5                                Data Analysis with R      4.6             18
# 7                  Introduction to R for Data Science      4.2             28
# 8    Introduction to Linear Models and Matrix Algebra      4.4             11
# 10                             Data Science: R Basics      4.6             10
# 14                                  Introduction to R      3.8             12
# 18                                   Statistics and R      3.5             20
# 44                          Explore Statistics with R      3.7             14
# 47  Introduction to Computational Finance and Fina...      3.5             11
#
#     provider                         institute  \
# 4    Kadenze  California Institute of the Arts
# 5    Udacity                          Facebook
# 7        edX                         Microsoft
# 8        edX                Harvard University
# 10       edX                Harvard University
# 14  Datacamp                                -1
# 18       edX                Harvard University
# 44       edX             Karolinska Institutet
# 47  Coursera          University of Washington
#
#                            Duration
# 4                                -1
# 5                                -1
# 7   2-3 hours a week , 4 weeks long
# 8   2-4 hours a week , 4 weeks long
# 10  1-2 hours a week , 8 weeks long
# 14                               -1
# 18  2-4 hours a week , 4 weeks long
# 44                               -1
# 47                               -1

# %%
# Best R Course Providers:


dist = bestR['provider'].value_counts()
colors = ['mediumturquoise', 'darkorange', 'gold', 'lightgreen']
trace = go.Pie(values=(np.array(dist)),labels=dist.index)
layout = go.Layout(title='Best R Course Providers')
data = [trace]
fig = go.Figure(trace,layout)
fig.update_traces(marker=dict(colors=colors, line=dict(color='#000000', width=2)))
fig.show()
py.plot(fig)
# Out:
# <div>
#
#
#             <div id="cbf946f5-326c-4f38-9956-d87d16fd07d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cbf946f5-326c-4f38-9956-d87d16fd07d9")) {
#                     Plotly.newPlot(
#                         'cbf946f5-326c-4f38-9956-d87d16fd07d9',
#                         [{"labels": ["edX", "Kadenze", "Coursera", "Datacamp", "Udacity"], "marker": {"colors": ["mediumturquoise", "darkorange", "gold", "lightgreen"], "line": {"color": "#000000", "width": 2}}, "type": "pie", "values": [5, 1, 1, 1, 1]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...
# 'https://plotly.com/~natassha/120/'

# %%
# Best R course institute

institute_count= pd.DataFrame({'institute':bestR["institute"].value_counts().index, 'counts':bestR["institute"].value_counts().values}).sort_values("counts")
institute_count = institute_count[institute_count.institute != '-1']
fig = px.bar(institute_count, x='institute', y='counts')
fig.update_traces(marker_color="darkred",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Best R Institute Counts')
py.plot(fig)
fig.show()
# Out:
# <div>
#
#
#             <div id="05c4d3e7-84bc-4042-a406-2835078c6433" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("05c4d3e7-84bc-4042-a406-2835078c6433")) {
#                     Plotly.newPlot(
#                         '05c4d3e7-84bc-4042-a406-2835078c6433',
#                         [{"alignmentgroup": "True", "hovertemplate": "institute=%{x}<br>counts=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "darkred", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Karolinska Institutet", "Microsoft", "Facebook", "California Institute of the Arts", "University of Washington", "Harvard University"], "xaxis": "x", "y": [1, 1, 1, 1, 1, 3], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %%
# Highest Rated R Courses: 

fig = px.bar(bestR.drop(bestR.index[0]), x='course', y='ratings')
fig.update_traces(marker_color="darkred",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Highest Rated R Courses')
py.plot(fig)
fig.show()
# Out:
# <div>
#
#
#             <div id="c9c9ba9e-3ed7-44bb-a060-b2a890311763" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c9c9ba9e-3ed7-44bb-a060-b2a890311763")) {
#                     Plotly.newPlot(
#                         'c9c9ba9e-3ed7-44bb-a060-b2a890311763',
#                         [{"alignmentgroup": "True", "hovertemplate": "course=%{x}<br>ratings=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "darkred", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Data Analysis with R", "Introduction to R for Data Science", "Introduction to Linear Models and Matrix Algebra", "Data Science: R Basics", "Introduction to R", "Statistics and R", "Explore Statistics with R", "Introduction to Computational Finance and Financial Econometrics"], "xaxis": "x", "y": [4.6, 4.2, 4.4, 4.6, 3.8, 3.5, 3.7, 3.5], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %%
# Best courses review num:

fig = px.bar(bestR.drop(bestR.index[0]), x='course', y='No_of_Reviews') 
fig.update_traces(marker_color="darkred",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Num of Reviews')
py.plot(fig)
fig.show()
# Out:
# <div>
#
#
#             <div id="61fb31cb-5521-4d05-a28f-5d0312567a85" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("61fb31cb-5521-4d05-a28f-5d0312567a85")) {
#                     Plotly.newPlot(
#                         '61fb31cb-5521-4d05-a28f-5d0312567a85',
#                         [{"alignmentgroup": "True", "hovertemplate": "course=%{x}<br>No_of_Reviews=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "darkred", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Data Analysis with R", "Introduction to R for Data Science", "Introduction to Linear Models and Matrix Algebra", "Data Science: R Basics", "Introduction to R", "Statistics and R", "Explore Statistics with R", "Introduction to Computational Finance and Financial Econometrics"], "xaxis": "x", "y": [18, 28, 11, 10, 12, 20, 14, 11], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %%
# Statistics:

# %%
driver.get('https://www.classcentral.com/search?q=statistics')
content = driver.page_source
soup = BeautifulSoup(content)
statsCourse = []
statsProvider = []
statsInstitute = []
statsRating = []
statsReview = []
statsDuration = []

# %%
for i in soup.findAll("span",{'class' : 'text-1 weight-semi line-tight'}):
    b = str(i)
    #print(b[find_1st(b,'>')+1:find_2nd(b,'<')])
    statsCourse.append(b[find_1st(b,'>')+1:find_2nd(b,'<')])

# %%
statsCoursee = []
for i in statsCourse:
    i = i.strip()
  #  print(i)
    statsCoursee.append(i)

# %%
# Institute:
st = []
for d in soup.findAll('div', attrs={'class':'truncate'}):
    abc = d.find('a', attrs={'class':'color-charcoal small-down-text-2 text-3'})
    if abc is not None:
        #print(rating.text)
        st.append(abc.text)
    else:
        st.append('-1')
for i in st:
    i = i.strip()
    #print(i)
    statsInstitute.append(i)

# %%
# Provider
statsProvider = []
for i in soup.findAll('a',href=True, attrs={'class':'color-charcoal italic'}):
    b = str(i)
   # print(b[find_1st(b,'>')+1:find_2nd(b,'<')])
    statsProvider.append(b[find_1st(b,'>')+1:find_2nd(b,'<')])
statsProviderr = []
for i in statsProvider:
    i = i.strip()
    #print(i)
    statsProviderr.append(i)

# %%
# Rating

sr = []
for d in soup.findAll('div', attrs={'class':'col border-box text-center nowrap row large-up-text-right padding-horz-small push'}):
    abc = d.find('span', attrs={'class':'xlarge-up-hidden color-charcoal text-center'})
    if abc is not None:
        #print(rating.text)
        sr.append(abc.text)
    else:
        sr.append('-1')
for i in sr:
    i = i.strip()
    #print(i)
    statsRating.append(i)

# %%
# Num of reviews:

revs = []
for d in soup.findAll('div', attrs={'class':'width-100'}):
    abc = d.find('span', attrs={'class':'large-down-hidden block line-tight text-4 color-gray'})
    if abc is not None:
        
        revs.append(abc.text)
    else:
        revs.append('-1')

# %%
revs = revs[5:-8]
for i in revs:
    i = i.strip()
    #print(i)
    statsReview.append(i)

# %%
# Duration:

sd = []
for d in soup.findAll('div', attrs={'class':'small-down-text-2 text-3 row vert-align-middle'}):
    abc = d.find('span', attrs={'class':'hidden medium-up-inline-block small-down-text-2 text-3 large-up-margin-left-xxsmall icon-clock-charcoal icon-left'})
    if abc is not None:
        sd.append(abc.text)
    else:
        sd.append('-1')

sdur = []
for i in sd:
    i = i.strip()
    #print(i)
    sdur.append(i) 
    
for i in sdur:
    i = ' '.join(i.split())
    i = i.replace('\n','')
    statsDuration.append(i)

# %%
# Create dataframe:
# Variables: statsCoursee, statsProviderr, rInstitute, rRating, rReview, rDuration

dfStats = pd.DataFrame({'course':statsCoursee,'ratings': statsRating,'No_of_Reviews':statsReview,
                  'provider':statsProviderr, 'institute':statsInstitute, 'Duration':statsDuration})
dfStats
# Out:
#                                                course ratings No_of_Reviews  \
# 0   Understanding Clinical Research: Behind the St...     4.8   484 Reviews
# 1                                          Statistics     5.0     5 Reviews
# 2                              Statistics in Medicine     5.0     6 Reviews
# 3                                    Basic Statistics     3.8    11 Reviews
# 4                         Statistics for Business – I     4.8     4 Reviews
# 5                                 Intro to Statistics     3.5    35 Reviews
# 6                     Intro to Inferential Statistics     4.5     8 Reviews
# 7                                 Bayesian Statistics     2.7    12 Reviews
# 8                        Statistics for Business - II     5.0     2 Reviews
# 9                       Six Sigma: Define and Measure     4.9   229 Reviews
# 10                                   Statistics and R     3.5    20 Reviews
# 11  Introduction to Statistics: Descriptive Statis...     4.8    10 Reviews
# 12         Bayesian Statistics: Techniques and Models     5.0     1 Reviews
# 13         I Heart Stats: Learning to Love Statistics     4.7     6 Reviews
# 14                             MathTrackX: Statistics      -1            -1
# 15                                Business Statistics      -1            -1
# 16       Python and Statistics for Financial Analysis     4.3   137 Reviews
# 17  Probability - The Science of Uncertainty and Data     4.9    29 Reviews
# 18           Statistics in Education for Mere Mortals     4.0     4 Reviews
# 19               Six Sigma: Analyze, Improve, Control     4.9   164 Reviews
# 20                             Inferential Statistics      -1            -1
# 21                         Introduction to Statistics     5.0     1 Reviews
# 22                                     Statistics One     3.3    18 Reviews
# 23                             Descriptive Statistics     5.0     1 Reviews
# 24                         Fundamentals of Statistics     5.0     4 Reviews
# 25                    Intro to Descriptive Statistics     4.0    12 Reviews
# 26                             Inferential Statistics     3.3     4 Reviews
# 27                                Statistics with SAS      -1            -1
# 28                Bayesian Statistics: Mixture Models      -1            -1
# 29      Probability and Statistics: To p or not to p?     4.7     3 Reviews
# 30  Bayesian Statistics: From Concept to Data Anal...     3.7     9 Reviews
# 31                         Statistics with R Capstone      -1            -1
# 32                   Statistics: Making Sense of Data     5.0     8 Reviews
# 33                Summary Statistics in Public Health      -1            -1
# 34            Introduction to Statistics: Probability     4.6     7 Reviews
# 35              Introduction to Statistics: Inference     5.0     3 Reviews
# 36  Foundations of Data Analysis - Part 1: Statist...     4.0     7 Reviews
# 37  Presentation skills: Speechwriting and Storyte...     4.8   201 Reviews
# 38          Linear Regression for Business Statistics      -1            -1
# 39  Inferential and Predictive Statistics for Busi...     4.5     2 Reviews
# 40                          Explore Statistics with R     3.7    14 Reviews
# 41              Improving your statistical inferences     5.0     1 Reviews
# 42  Probability Theory, Statistics and Exploratory...      -1            -1
# 43  Introduction to Probability, Statistics, and R...     3.3     3 Reviews
# 44  Introduction to Statistics &amp; Data Analysis...      -1            -1
# 45  Global Statistics - Composite Indices for Inte...      -1            -1
# 46               Preparing for the AP Statistics Exam     5.0     1 Reviews
# 47            Statistics: Unlocking the World of Data     4.0     2 Reviews
# 48  Foundations of Data Analysis - Part 2: Inferen...     3.5     2 Reviews
# 49  Introduction to Statistics for the Social Scie...     3.5     4 Reviews
#
#             provider                                          institute  \
# 0           Coursera                            University of Cape Town
# 1            Udacity                          San Jose State University
# 2   Stanford OpenEdx                                Stanford University
# 3           Coursera                            University of Amsterdam
# 4                edX           Indian Institute of Management Bangalore
# 5            Udacity                                Stanford University
# 6            Udacity                          San Jose State University
# 7           Coursera                                    Duke University
# 8                edX           Indian Institute of Management Bangalore
# 9                edX  Technische Universität München (Technical Univ...
# 10               edX                                 Harvard University
# 11               edX                 University of California, Berkeley
# 12          Coursera               University of California, Santa Cruz
# 13               edX                           University of Notre Dame
# 14               edX                             University of Adelaide
# 15            Swayam             Indian Institute of Technology Roorkee
# 16          Coursera  The Hong Kong University of Science and Techno...
# 17               edX              Massachusetts Institute of Technology
# 18    Canvas Network                                                 -1
# 19               edX  Technische Universität München (Technical Univ...
# 20          Coursera                            University of Amsterdam
# 21            Stepik                           Bioinformatics Institute
# 22          Coursera                               Princeton University
# 23          Coursera                            University of Amsterdam
# 24               edX              Massachusetts Institute of Technology
# 25           Udacity                          San Jose State University
# 26          Coursera                            University of Amsterdam
# 27          Coursera                                                SAS
# 28          Coursera               University of California, Santa Cruz
# 29          Coursera      University of London International Programmes
# 30          Coursera               University of California, Santa Cruz
# 31          Coursera                                    Duke University
# 32          Coursera                              University of Toronto
# 33          Coursera                           Johns Hopkins University
# 34               edX                 University of California, Berkeley
# 35               edX                 University of California, Berkeley
# 36               edX                  The University of Texas at Austin
# 37          Coursera                             Tomsk State University
# 38          Coursera                                    Rice University
# 39          Coursera         University of Illinois at Urbana-Champaign
# 40               edX                              Karolinska Institutet
# 41          Coursera                 Eindhoven University of Technology
# 42          Coursera                         Higher School of Economics
# 43       Independent                University of Massachusetts Amherst
# 44          Coursera                            Imperial College London
# 45          Coursera                               University of Geneva
# 46               edX                         Tennessee Board of Regents
# 47               edX                            University of Edinburgh
# 48               edX                  The University of Texas at Austin
# 49          Coursera                               University of Zurich
#
#                                      Duration
# 0                                          -1
# 1                                          -1
# 2                                          -1
# 3                                          -1
# 4             2-4 hours a week , 5 weeks long
# 5                                          -1
# 6                                          -1
# 7                                          -1
# 8             2-4 hours a week , 7 weeks long
# 9             3-4 hours a week , 8 weeks long
# 10            2-4 hours a week , 4 weeks long
# 11                                         -1
# 12                                         -1
# 13            4-6 hours a week , 4 weeks long
# 14            3-6 hours a week , 4 weeks long
# 15                                         -1
# 16            3-4 hours a week , 4 weeks long
# 17         10-14 hours a week , 16 weeks long
# 18                                         -1
# 19            3-4 hours a week , 8 weeks long
# 20            1-3 hours a week , 7 weeks long
# 21                                         -1
# 22                                         -1
# 23            4-8 hours a week , 6 weeks long
# 24         10-14 hours a week , 18 weeks long
# 25                                         -1
# 26            4-8 hours a week , 7 weeks long
# 27              9 hours a week , 5 weeks long
# 28  21 hours worth of material , 5 weeks long
# 29           5-10 hours a week , 6 weeks long
# 30                                         -1
# 31           5-10 hours a week , 8 weeks long
# 32           6-8 hours a week , 47 weeks long
# 33            3-4 hours a week , 4 weeks long
# 34                                         -1
# 35                                         -1
# 36            3-6 hours a week , 6 weeks long
# 37                                         -1
# 38                                         -1
# 39                                         -1
# 40                                         -1
# 41                                         -1
# 42          10-16 hours a week , 6 weeks long
# 43                                         -1
# 44            2-5 hours a week , 4 weeks long
# 45              3 hours a week , 5 weeks long
# 46         10-15 hours a week , 35 weeks long
# 47            4-6 hours a week , 8 weeks long
# 48            3-6 hours a week , 6 weeks long
# 49                                         -1

# %%
# Rating:
dfStats['ratings'] = dfStats['ratings'].astype(float)
statsRating = dfStats.dropna()
statsRating = statsRating[statsRating.ratings != -1]
np.mean(statsRating['ratings']) # mean rating is 4.36
# Out:
# 4.358974358974359

# %%
# Visualize overall ratings
fig = px.histogram(statsRating, x="ratings")
fig.update_traces(marker_color="pink",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Statistics Course Ratings')
fig.show()
py.plot(fig)
# Out:
# <div>
#
#
#             <div id="51ae6b70-fda5-43f2-9144-d76b8130d10a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("51ae6b70-fda5-43f2-9144-d76b8130d10a")) {
#                     Plotly.newPlot(
#                         '51ae6b70-fda5-43f2-9144-d76b8130d10a',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "ratings=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "pink", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [4.8, 5.0, 5.0, 3.8, 4.8, 3.5, 4.5, 2.7, 5.0, 4.9, 3.5, 4.8, 5.0, 4.7, 4.3, 4.9, 4.0, 4.9, 5.0, 3.3, 5.0, 5.0, 4.0, 3.3, 4.7, 3.7, 5.0, 4.6, 5.0, 4.0, 4.8, 4.5, 3.7, 5.0, 3.3, 5.0, 4.0, 3.5, 3.5], "xaxis": "x", "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...
# 'https://plotly.com/~natassha/126/'

# %%
# No.of.Reviews:

statsRating['No_of_Reviews'] = statsRating['No_of_Reviews'].str.extract('(\d+)', expand=False).astype(int)
np.mean(statsRating['No_of_Reviews']) # mean num of reviews: 38
# Out:
# 37.794871794871796

# %%
# All course review num
fig = px.histogram(statsRating, x="No_of_Reviews")
fig.update_traces(marker_color="pink",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Num of Reviews')
fig.show()
py.plot(fig)
# Out:
# <div>
#
#
#             <div id="d5c780d0-ebbb-4bf4-801b-ddc1c98b2531" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d5c780d0-ebbb-4bf4-801b-ddc1c98b2531")) {
#                     Plotly.newPlot(
#                         'd5c780d0-ebbb-4bf4-801b-ddc1c98b2531',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "No_of_Reviews=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "pink", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [484, 5, 6, 11, 4, 35, 8, 12, 2, 229, 20, 10, 1, 6, 137, 29, 4, 164, 1, 18, 1, 4, 12, 4, 3, 9, 8, 7, 3, 7, 201, 2, 14, 1, 3, 1, 2, 2, 4], "xaxis": "x", "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...
# 'https://plotly.com/~natassha/128/'

# %%
# best stats courses:
bestStats = statsRating.loc[(statsRating['No_of_Reviews'] >= 7) & 
                         (statsRating['ratings'] >= 4)]
bestStats
# Out:
#                                                course  ratings  No_of_Reviews  \
# 0   Understanding Clinical Research: Behind the St...      4.8            484
# 6                     Intro to Inferential Statistics      4.5              8
# 9                       Six Sigma: Define and Measure      4.9            229
# 11  Introduction to Statistics: Descriptive Statis...      4.8             10
# 16       Python and Statistics for Financial Analysis      4.3            137
# 17  Probability - The Science of Uncertainty and Data      4.9             29
# 19               Six Sigma: Analyze, Improve, Control      4.9            164
# 25                    Intro to Descriptive Statistics      4.0             12
# 32                   Statistics: Making Sense of Data      5.0              8
# 34            Introduction to Statistics: Probability      4.6              7
# 36  Foundations of Data Analysis - Part 1: Statist...      4.0              7
# 37  Presentation skills: Speechwriting and Storyte...      4.8            201
#
#     provider                                          institute  \
# 0   Coursera                            University of Cape Town
# 6    Udacity                          San Jose State University
# 9        edX  Technische Universität München (Technical Univ...
# 11       edX                 University of California, Berkeley
# 16  Coursera  The Hong Kong University of Science and Techno...
# 17       edX              Massachusetts Institute of Technology
# 19       edX  Technische Universität München (Technical Univ...
# 25   Udacity                          San Jose State University
# 32  Coursera                              University of Toronto
# 34       edX                 University of California, Berkeley
# 36       edX                  The University of Texas at Austin
# 37  Coursera                             Tomsk State University
#
#                               Duration
# 0                                   -1
# 6                                   -1
# 9      3-4 hours a week , 8 weeks long
# 11                                  -1
# 16     3-4 hours a week , 4 weeks long
# 17  10-14 hours a week , 16 weeks long
# 19     3-4 hours a week , 8 weeks long
# 25                                  -1
# 32    6-8 hours a week , 47 weeks long
# 34                                  -1
# 36     3-6 hours a week , 6 weeks long
# 37                                  -1

# %%
# Best stats Course Providers:

dist = bestStats['provider'].value_counts()
colors = ['mediumturquoise', 'darkorange', 'gold', 'lightgreen']
trace = go.Pie(values=(np.array(dist)),labels=dist.index)
layout = go.Layout(title='Best Statistics Course Providers')
data = [trace]
fig = go.Figure(trace,layout)
fig.update_traces(marker=dict(colors=colors, line=dict(color='#000000', width=2)))
fig.show()
#py.plot(fig)
# Out:
# <div>
#
#
#             <div id="fc3bd985-8582-4ae2-975c-544b02d79073" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fc3bd985-8582-4ae2-975c-544b02d79073")) {
#                     Plotly.newPlot(
#                         'fc3bd985-8582-4ae2-975c-544b02d79073',
#                         [{"labels": ["edX", "Coursera", "Udacity"], "marker": {"colors": ["mediumturquoise", "darkorange", "gold", "lightgreen"], "line": {"color": "#000000", "width": 2}}, "type": "pie", "values": [6, 4, 2]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %%
# Best Stats course institute

institute_count= pd.DataFrame({'institute':bestStats["institute"].value_counts().index, 'counts':bestStats["institute"].value_counts().values}).sort_values("counts")
institute_count = institute_count[institute_count.institute != '-1']
fig = px.bar(institute_count, x='institute', y='counts')
fig.update_traces(marker_color="pink",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Best Statistics Institute Counts')
#py.plot(fig)
fig.show()
# Out:
# <div>
#
#
#             <div id="9b5cf265-83f3-49cb-9ff6-3e54ff03c344" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9b5cf265-83f3-49cb-9ff6-3e54ff03c344")) {
#                     Plotly.newPlot(
#                         '9b5cf265-83f3-49cb-9ff6-3e54ff03c344',
#                         [{"alignmentgroup": "True", "hovertemplate": "institute=%{x}<br>counts=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "pink", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["The Hong Kong University of Science and Technology", "The University of Texas at Austin", "Tomsk State University", "University of Cape Town", "University of Toronto", "Massachusetts Institute of Technology", "University of California, Berkeley", "Technische Universit\u00e4t M\u00fcnchen (Technical University of Munich)", "San Jose State University"], "xaxis": "x", "y": [1, 1, 1, 1, 1, 1, 2, 2, 2], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %%
# Highest Rated Stats Courses: 

fig = px.bar(bestStats.drop(bestStats.index[0]), x='course', y='ratings')
fig.update_traces(marker_color="pink",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Highest Rated Statistics Courses')
py.plot(fig)
fig.show()
# Out:
# <div>
#
#
#             <div id="dfa32edb-75c9-4be2-99d9-116b0d9799fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dfa32edb-75c9-4be2-99d9-116b0d9799fb")) {
#                     Plotly.newPlot(
#                         'dfa32edb-75c9-4be2-99d9-116b0d9799fb',
#                         [{"alignmentgroup": "True", "hovertemplate": "course=%{x}<br>ratings=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "pink", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Intro to Inferential Statistics", "Six Sigma: Define and Measure", "Introduction to Statistics: Descriptive Statistics", "Python and Statistics for Financial Analysis", "Probability - The Science of Uncertainty and Data", "Six Sigma: Analyze, Improve, Control", "Intro to Descriptive Statistics", "Statistics: Making Sense of Data", "Introduction to Statistics: Probability", "Foundations of Data Analysis - Part 1: Statistics Using R", "Presentation skills: Speechwriting and Storytelling"], "xaxis": "x", "y": [4.5, 4.9, 4.8, 4.3, 4.9, 4.9, 4.0, 5.0, 4.6, 4.0, 4.8], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %%
# Best courses review num:

fig = px.bar(bestStats.drop(bestStats.index[0]), x='course', y='No_of_Reviews') 
fig.update_traces(marker_color="pink",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Num of Reviews')
py.plot(fig)
fig.show()
# Out:
# <div>
#
#
#             <div id="c06c86cb-2a2c-4e0a-ac0e-669dc9690152" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c06c86cb-2a2c-4e0a-ac0e-669dc9690152")) {
#                     Plotly.newPlot(
#                         'c06c86cb-2a2c-4e0a-ac0e-669dc9690152',
#                         [{"alignmentgroup": "True", "hovertemplate": "course=%{x}<br>No_of_Reviews=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "pink", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Intro to Inferential Statistics", "Six Sigma: Define and Measure", "Introduction to Statistics: Descriptive Statistics", "Python and Statistics for Financial Analysis", "Probability - The Science of Uncertainty and Data", "Six Sigma: Analyze, Improve, Control", "Intro to Descriptive Statistics", "Statistics: Making Sense of Data", "Introduction to Statistics: Probability", "Foundations of Data Analysis - Part 1: Statistics Using R", "Presentation skills: Speechwriting and Storytelling"], "xaxis": "x", "y": [8, 229, 10, 137, 29, 164, 12, 8, 7, 7, 201], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...
